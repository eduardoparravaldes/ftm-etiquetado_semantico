# %% [markdown]
# # Consumer

# %% [markdown]
# Leemos los mensajes del topic de Kafka e insertamos en ElasticSearch las palabras.
# primero ejecutamos el consumer y luego el producer.

# %%
#from kafka import KafkaConsumer
#consumer = KafkaConsumer('palabras',bootstrap_servers=['localhost:9092'])
#for msg in consumer:
     #print (msg)

# %%
from kafka import KafkaConsumer

# To consume latest messages and auto-commit offsets
consumer = KafkaConsumer('palabras',bootstrap_servers=['localhost:9092'])

#connect to our cluster
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host': 'localhost', 'port': 9200}])


contador = {} # diccionario para guardar ocurrencia de palabras
grupo = {} # diccionario para agrupar palabras según su longitud
for message in consumer:
    # message value and key are raw bytes -- decode if necessary!
    # e.g., for unicode: `message.value.decode('utf-8')`
    print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                          message.offset, message.key,
                                          message.value))
    palabra = message.value
    
    es.index(index='palabras', doc_type='strings', body={
        "name": palabra,
        "longitud":len(palabra),
        "tag": "palabra del libro quijote"
    })
# Out:
# palabras:0:5646: key=None value=en
# palabras:0:5647: key=None value=un
# palabras:0:5648: key=None value=lugar
# palabras:0:5649: key=None value=de
# palabras:0:5650: key=None value=la
# palabras:0:5651: key=None value=mancha
# palabras:0:5652: key=None value=de
# palabras:0:5653: key=None value=cuyo
# palabras:0:5654: key=None value=nombre
# palabras:0:5655: key=None value=no
# palabras:0:5656: key=None value=quiero
# palabras:0:5657: key=None value=acordarme
# palabras:0:5658: key=None value=no
# palabras:0:5659: key=None value=ha
# palabras:0:5660: key=None value=mucho
# palabras:0:5661: key=None value=tiempo
# palabras:0:5662: key=None value=que
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-82c4693ed694> in <module>()
#      16     print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
#      17                                           message.offset, message.key,
# ---> 18                                           message.value))
#      19     palabra = message.value
#      20
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 3: ordinal not in range(128)

# %%
#delete test data and try with something more interesting
#es.indices.delete(index='books', ignore=[400, 404])

# %%
# Abrir archivo para lectura
nombrearchivo = 'mwes_es.usas.txt'
with open(nombrearchivo) as archivo:
    for linea in archivo:
        palabras = linea.split() # separar línea en palabras, por espacio en blanco
        print(palabras)
        #for palabra in palabras:
            #palabra = palabra.strip(".,") # cambiar a minúscula y quitar puntuación
            
               

# Cerrar archivo al finalizar
archivo.close()
# Mostrar información
print('Terminado...:')
# Out:
# ['#Spanish', 'Semantic', 'MWE', 'Lexicon.', 'Clean', 'Version.', 'Last', 'updated:', '26', 'April', '2017.']
# ['#Contributors', 'include:']
# ['#Ricardo-Mar\xc3\xada', 'Jim\xc3\xa9nez', 'of', 'UICbarcelona', '(International', 'University', 'of', 'Catalonia),', 'Barcelona,', 'Spain;']
# ['#Hugo', 'Sanjurjo', 'Gonz\xc3\xa1lez,', 'University', 'of', 'Le\xc3\xb3n,', 'Spain;']
# ['#Carlos', 'Herrero', 'of', 'Autonomous', 'University', 'of', 'Madrid', '(UAM),', 'Spain.']
# ['#Lexicon', 'editors:', 'Scott', 'Piao', '&', 'Paul', 'Rayson,', 'UCREL,', 'Lancaster', 'University,', 'UK.']
# []
# ['A_pnoun', 'Arnoia_pnoun', 'Z2']
# ['A_pnoun', 'Ba\xc3\xb1a_pnoun', 'Z2']
# ['A_pnoun', 'Bola_pnoun', 'Z2']
# ['A_pnoun', 'Ca\xc3\xb1iza_pnoun', 'Z2']
# ['A_pnoun', 'Capela_pnoun', 'Z2']
# ['A_pnoun', 'Coru\xc3\xb1a_pnoun', 'Z2']
# ['A_pnoun', 'Estrada_pnoun', 'Z2']
# ['A_pnoun', 'Fonsagrada_pnoun', 'Z2']
# ['A_pnoun', 'Guarda_pnoun', 'Z2']
# ['A_pnoun', 'Gudi\xc3\xb1a_pnoun', 'Z2']
# ['A_pnoun', 'Illa_pnoun', 'de_pnoun', 'Arousa_pnoun', 'Z2']
# ['A_pnoun', 'Lama_pnoun', 'Z2']
# ['A_pnoun', 'Laracha_pnoun', 'Z2']
# ['A_pnoun', 'Merca_pnoun', 'Z2']
# ['A_pnoun', 'Mezquita_pnoun', 'Z2']
# ['A_pnoun', 'Nevess_pnoun', 'Z2']
# ['A_pnoun', 'Nogaiss_pnoun', 'Z2']
# ['A_pnoun', 'Pastoriza_pnoun', 'Z2']
# ['A_pnoun', 'Peroxa_pnoun', 'Z2']
# ['A_pnoun', 'Pobra_pnoun', 'de_pnoun', 'Trives_pnoun', 'Z2']
# ['A_pnoun', 'Pobra_pnoun', 'Do_pnoun', 'Broll\xc3\xb3n_pnoun', 'Z2']
# ['A_pnoun', 'Pobra_pnoun', 'Do_pnoun', 'Carami\xc3\xb1al_pnoun', 'Z2']
# ['A_pnoun', 'Pontenova_pnoun', 'Z2']
# ['A_pnoun', 'Pontes_pnoun', 'de_pnoun', 'Garc\xc3\xada_pnoun', 'Rodr\xc3\xadguezs_pnoun', 'Z2']
# ['A_pnoun', 'R\xc3\xbaa_pnoun', 'Z2']
# ['A_pnoun', 'Somozass_pnoun', 'Z2']
# ['A_pnoun', 'Teixeira_pnoun', 'Z2']
# ['A_pnoun', 'Veiga_pnoun', 'Z2']
# ['a_prep', 'carta_noun', 'cabal_adj', 'A4', 'A5.1']
# ['a_prep', 'machamartillo_noun', 'S1.2.5']
# ['a_prep', 'pie_noun', 'juntillas_noun', 'A5', 'S3', 'X2.2']
# ['a_prep', 'trancas_noun', 'y_conj', 'barrancas_noun', 'A12']
# ['a_prep', 'troche_noun', 'y_conj', 'moche_noun', 'A13.2', 'X2.5']
# ['Aar\xc3\xb3n_pnoun', 'Sarmiento_pnoun', 'Z2']
# ['Aar\xc3\xb3n_pnoun', 'Sarmiento_pnoun', 'Padilla_pnoun', 'Z2']
# ['Aauri_pnoun', 'Bokesa_pnoun', 'Z2']
# ['Abanto_pnoun', 'y_pnoun', 'Ci\xc3\xa9rvana-Abanto_pnoun', 'Zierbena_pnoun', 'Z2']
# ['Abarca_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Abaurrea_pnoun', 'Alta_pnoun', 'Z2']
# ['Abaurrea_pnoun', 'Baja_pnoun', 'Z2']
# ['Abella_pnoun', 'de_pnoun', 'la_pnoun', 'Conca_pnoun', 'Z2']
# ['Abia_pnoun', 'de_pnoun', 'la_pnoun', 'Obispal\xc3\xada_pnoun', 'Z2']
# ['Abia_pnoun', 'de_pnoun', 'las_pnoun', 'Torres_pnoun', 'Z2']
# ['Abu_pnoun', 'Dabi_pnoun', 'Z2']
# ['acercarse_fw', 'al_port', 'sol_noun', 'que_pron', 'm\xc3\xa1s_adv', 'calienta_verb', 'S7', 'X5.2']
# ['acordarse_fw', 'de_prep', 'Santa_adj', 'B\xc3\xa1rbara_noun', 'cuando_conj', 'truena_verb', 'T2', 'T4']
# ['Ad\xc3\xads_pnoun', 'Abeba_pnoun', 'Z2']
# ['Adrada_pnoun', 'de_pnoun', 'Haza_pnoun', 'Z2']
# ['Adrada_pnoun', 'de_pnoun', 'Pir\xc3\xb3n_pnoun', 'Z2']
# ['Aguas_pnoun', 'C\xc3\xa1ndidas_pnoun', 'Z2']
# ['Aguilar_pnoun', 'de_pnoun', 'Bureba_pnoun', 'Z2']
# ['Aguilar_pnoun', 'de_pnoun', 'Campoo_pnoun', 'Z2']
# ['Aguilar_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Aguilar_pnoun', 'de_pnoun', 'Cod\xc3\xa9s_pnoun', 'Z2']
# ['Aguilar_pnoun', 'de_pnoun', 'la_pnoun', 'Frontera_pnoun', 'Z2']
# ['Aguilar_pnoun', 'de_pnoun', 'Segarra_pnoun', 'Z2']
# ['Aguilar_pnoun', 'del_pnoun', 'Alfambra_pnoun', 'Z2']
# ['Aguilar_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Alhama_pnoun', 'Z2']
# ['Ahigal_pnoun', 'de_pnoun', 'los_pnoun', 'Aceiteros_pnoun', 'Z2']
# ['Ahigal_pnoun', 'de_pnoun', 'Villarino_pnoun', 'Z2']
# ['Ahuecar_verb', 'el_art', 'ala_noun', 'T1']
# ['Aielo_pnoun', 'de_pnoun', 'Malferit_pnoun', 'Z2']
# ['Aielo_pnoun', 'de_pnoun', 'Rugat_pnoun', 'Z2']
# ['Ainhoa_pnoun', 'Murua_pnoun', 'Z2']
# ['Ainhoa_pnoun', 'Mur\xc3\xbaa_pnoun', 'Z2']
# ['Ainhoa_pnoun', 'Murua_pnoun', 'Zubizarreta_pnoun', 'Z2']
# ['Ainhoa_pnoun', 'Mur\xc3\xbaa_pnoun', 'Zubizarreta_pnoun', 'Z2']
# ['Ajamil_pnoun', 'de_pnoun', 'Cameros_pnoun', 'Z2']
# ['Alag\xc3\xb3n_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Alameda_pnoun', 'de_pnoun', 'la_pnoun', 'Sagra_pnoun', 'Z2']
# ['Alameda_pnoun', 'del_pnoun', 'Valle_pnoun', 'Z2']
# ['Alar_pnoun', 'del_pnoun', 'Rey_pnoun', 'Z2']
# ['Al\xc3\xa0s_pnoun', 'I_pnoun', 'Cerc_pnoun', 'Z2']
# ['Alba_pnoun', 'de_pnoun', 'Cerrato_pnoun', 'Z2']
# ['Alba_pnoun', 'de_pnoun', 'Tormes_pnoun', 'Z2']
# ['Alba_pnoun', 'de_pnoun', 'Yeltes_pnoun', 'Z2']
# ['Alba_pnoun', 'Mar\xc3\xada_pnoun', 'Cabello_pnoun', 'Z2']
# ['Alba_pnoun', 'Mar\xc3\xada_pnoun', 'Cabello_pnoun', 'Rodilla_pnoun', 'Z2']
# ['Alba_pnoun', 'Torrens_pnoun', 'Z2']
# ['Alba_pnoun', 'Torrens_pnoun', 'Salom_pnoun', 'Z2']
# ['Albaida_pnoun', 'del_pnoun', 'Aljarafe_pnoun', 'Z2']
# ['Albaladejo_pnoun', 'del_pnoun', 'Cuende_pnoun', 'Z2']
# ['Albalat_pnoun', 'de_pnoun', 'la_pnoun', 'Ribera_pnoun', 'Z2']
# ['Albalat_pnoun', 'Dels_pnoun', 'Sorells_pnoun', 'Z2']
# ['Albalat_pnoun', 'Dels_pnoun', 'Tarongers_pnoun', 'Z2']
# ['Albalate_pnoun', 'de_pnoun', 'Cinca_pnoun', 'Z2']
# ['Albalate_pnoun', 'de_pnoun', 'las_pnoun', 'Nogueras_pnoun', 'Z2']
# ['Albalate_pnoun', 'de_pnoun', 'Zorita_pnoun', 'Z2']
# ['Albalate_pnoun', 'del_pnoun', 'Arzobispo_pnoun', 'Z2']
# ['Albanchez_pnoun', 'de_pnoun', 'M\xc3\xa1gina_pnoun', 'Z2']
# ['Albarreal_pnoun', 'de_pnoun', 'Tajo_pnoun', 'Z2']
# ['Albelda_pnoun', 'de_pnoun', 'Iregua_pnoun', 'Z2']
# ['Alberite_pnoun', 'de_pnoun', 'San_pnoun', 'Juan_pnoun', 'Z2']
# ['Albero_pnoun', 'Alto_pnoun', 'Z2']
# ['Albero_pnoun', 'Bajo_pnoun', 'Z2']
# ['Albert_pnoun', 'Rocas_pnoun', 'Z2']
# ['Albert_pnoun', 'Rocas_pnoun', 'Comas_pnoun', 'Z2']
# ['Albert_pnoun', 'Sala_pnoun', 'Z2']
# ['Albert_pnoun', 'Sala_pnoun', 'Moreno_pnoun', 'Z2']
# ['Albert_pnoun', 'Torres_pnoun', 'Z2']
# ['Albert_pnoun', 'Torres_pnoun', 'Barcel\xc3\xb3_pnoun', 'Z2']
# ['Alberto_pnoun', 'Contador_pnoun', 'Z2']
# ['Alberto_pnoun', 'Contador_pnoun', 'Velasco_pnoun', 'Z2']
# ['Alberto_pnoun', 'Dom\xc3\xadnguez_pnoun', 'Lorenzo_pnoun', 'Z2']
# ['Alberto_pnoun', 'Entrerr\xc3\xados_pnoun', 'Z2']
# ['Alberto_pnoun', 'Entrerr\xc3\xados_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Z2']
# ['Alberto_pnoun', 'Fern\xc3\xa1ndez_pnoun', 'Z2']
# ['Alberto_pnoun', 'Fern\xc3\xa1ndez_pnoun', 'Mu\xc3\xb1oz_pnoun', 'Z2']
# ['Alberto_pnoun', 'Garc\xc3\xada_pnoun', 'Z2']
# ['Alberto_pnoun', 'Garc\xc3\xada_pnoun', 'Fern\xc3\xa1ndez_pnoun', 'Z2']
# ['Alberto_pnoun', 'Ruiz-Gallard\xc3\xb3n_pnoun', 'Z2']
# ['Alberto_pnoun', 'Ruiz-Gallard\xc3\xb3n_pnoun', 'Jim\xc3\xa9nez_pnoun', 'Z2']
# ['Alberuela_pnoun', 'de_pnoun', 'Tubo_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'de_pnoun', 'Ebro_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'de_pnoun', 'Guada\xc3\xadra_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'de_pnoun', 'Gurrea_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'de_pnoun', 'Henares_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'de_pnoun', 'la_pnoun', 'Selva_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'de_pnoun', 'la_pnoun', 'Vega_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'de_pnoun', 'los_pnoun', 'Gazules_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'de_pnoun', 'Moncayo_pnoun', 'Z2']
# ['Alcal\xc3\xa0_pnoun', 'de_pnoun', 'Xivert_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'del_pnoun', 'J\xc3\xbacar_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'del_pnoun', 'Obispo_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'del_pnoun', 'Valle_pnoun', 'Z2']
# ['Alcal\xc3\xa1_pnoun', 'la_pnoun', 'Real_pnoun', 'Z2']
# ['Alc\xc3\xa0ntera_pnoun', 'de_pnoun', 'X\xc3\xbaquer_pnoun', 'Z2']
# ['Alcaudete_pnoun', 'de_pnoun', 'la_pnoun', 'Jara_pnoun', 'Z2']
# ['Alc\xc3\xa1zar_pnoun', 'de_pnoun', 'San_pnoun', 'Juan_pnoun', 'Z2']
# ['Alc\xc3\xa1zar_pnoun', 'del_pnoun', 'Rey_pnoun', 'Z2']
# ['Alcocer_pnoun', 'de_pnoun', 'Planes_pnoun', 'Z2']
# ['Alcocero_pnoun', 'de_pnoun', 'Mola_pnoun', 'Z2']
# ['Alcolea_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Alcolea_pnoun', 'de_pnoun', 'Cinca_pnoun', 'Z2']
# ['Alcolea_pnoun', 'de_pnoun', 'las_pnoun', 'Pe\xc3\xb1as_pnoun', 'Z2']
# ['Alcolea_pnoun', 'de_pnoun', 'Tajo_pnoun', 'Z2']
# ['Alcolea_pnoun', 'del_pnoun', 'Pinar_pnoun', 'Z2']
# ['Alcolea_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Alconada_pnoun', 'de_pnoun', 'Maderuelo_pnoun', 'Z2']
# ['Alconchel_pnoun', 'de_pnoun', 'Ariza_pnoun', 'Z2']
# ['Alconchel_pnoun', 'de_pnoun', 'la_pnoun', 'Estrella_pnoun', 'Z2']
# ['Alcubilla_pnoun', 'de_pnoun', 'Avellaneda_pnoun', 'Z2']
# ['Alcubilla_pnoun', 'de_pnoun', 'las_pnoun', 'Pe\xc3\xb1as_pnoun', 'Z2']
# ['Alcubilla_pnoun', 'de_pnoun', 'Nogales_pnoun', 'Z2']
# ['Alcudia_pnoun', 'de_pnoun', 'Monteagud_pnoun', 'Z2']
# ['Alcudia_pnoun', 'de_pnoun', 'Veo_pnoun', 'Z2']
# ['Aldea_pnoun', 'de_pnoun', 'San_pnoun', 'Miguel_pnoun', 'Z2']
# ['Aldea_pnoun', 'del_pnoun', 'Cano_pnoun', 'Z2']
# ['Aldea_pnoun', 'del_pnoun', 'Fresno_pnoun', 'Z2']
# ['Aldea_pnoun', 'del_pnoun', 'Obispo_pnoun', 'Z2']
# ['Aldea_pnoun', 'del_pnoun', 'Rey_pnoun', 'Z2']
# ['Aldea_pnoun', 'En_pnoun', 'Cabo_pnoun', 'Z2']
# ['Aldea_pnoun', 'Real_pnoun', 'Z2']
# ['Aldead\xc3\xa1vila_pnoun', 'de_pnoun', 'la_pnoun', 'Ribera_pnoun', 'Z2']
# ['Aldealengua_pnoun', 'de_pnoun', 'Pedraza_pnoun', 'Z2']
# ['Aldealengua_pnoun', 'de_pnoun', 'Santa_pnoun', 'Mar\xc3\xada_pnoun', 'Z2']
# ['Aldeamayor_pnoun', 'de_pnoun', 'San_pnoun', 'Mart\xc3\xadn_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'Barbarroya_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'Ebro_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'Figueroa_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'Guadalajara_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Serrezuela_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Vera_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'San_pnoun', 'Bartolom\xc3\xa9_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'de_pnoun', 'Santa_pnoun', 'Cruz_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'del_pnoun', 'Camino_pnoun', 'Z2']
# ['Aldeanueva_pnoun', 'del_pnoun', 'Codonal_pnoun', 'Z2']
# ['Aldeaseca_pnoun', 'de_pnoun', 'Alba_pnoun', 'Z2']
# ['Aldeaseca_pnoun', 'de_pnoun', 'la_pnoun', 'Frontera_pnoun', 'Z2']
# ['Aldeavieja_pnoun', 'de_pnoun', 'Tormes_pnoun', 'Z2']
# ['Aldehuela_pnoun', 'de_pnoun', 'Jerte_pnoun', 'Z2']
# ['Aldehuela_pnoun', 'de_pnoun', 'la_pnoun', 'B\xc3\xb3veda_pnoun', 'Z2']
# ['Aldehuela_pnoun', 'de_pnoun', 'Liestos_pnoun', 'Z2']
# ['Aldehuela_pnoun', 'de_pnoun', 'Peri\xc3\xa1\xc3\xb1ez_pnoun', 'Z2']
# ['Aldehuela_pnoun', 'de_pnoun', 'Yeltes_pnoun', 'Z2']
# ['Aldehuela_pnoun', 'del_pnoun', 'Codonal_pnoun', 'Z2']
# ['Alejandra_pnoun', 'Quereda_pnoun', 'Z2']
# ['Alejandro_pnoun', 'Barrenechea_pnoun', 'Z2']
# ['Alejandro_pnoun', 'Lerroux_pnoun', 'Z2']
# ['Alejandro_pnoun', 'Valverde_pnoun', 'Z2']
# ['Alejandro_pnoun', 'Valverde_pnoun', 'Belmonte_pnoun', 'Z2']
# ['Alemayehu_pnoun', 'Bezabeh_pnoun', 'Z2']
# ['Alemayehu_pnoun', 'Bezabeh_pnoun', 'Desta_pnoun', 'Z2']
# ['Alessandra_pnoun', 'Aguilar_pnoun', 'Z2']
# ['Alessandra_pnoun', 'Aguilar_pnoun', 'Mor\xc3\xa1n_pnoun', 'Z2']
# ['Alex_pnoun', 'F\xc3\xa1bregas_pnoun', 'Z2']
# ['Alex_pnoun', 'F\xc3\xa0bregas_pnoun', 'Z2']
# ['Alex_pnoun', 'F\xc3\xa0bregas_pnoun', 'Carn\xc3\xa9_pnoun', 'Z2']
# ['\xc3\x81lex_pnoun', 'Mumbr\xc3\xba_pnoun', 'Z2']
# ['\xc3\x81lex_pnoun', 'Mumbr\xc3\xba_pnoun', 'Murcia_pnoun', 'Z2']
# ['Alexandre_pnoun', 'F\xc3\xa0bregas_pnoun', 'Z2']
# ['Alfara_pnoun', 'de_pnoun', 'Carles_pnoun', 'Z2']
# ['Alfara_pnoun', 'de_pnoun', 'la_pnoun', 'Baronia_pnoun', 'Z2']
# ['Alfara_pnoun', 'del_pnoun', 'Patriarca_pnoun', 'Z2']
# ['Alfaraz_pnoun', 'de_pnoun', 'Sayago_pnoun', 'Z2']
# ['Alfonso_pnoun', 'Alonso_pnoun', 'Aranegui_pnoun', 'Z2']
# ['Alfonso_pnoun', 'Benavides_pnoun', 'Z2']
# ['Alfonso_pnoun', 'Mar\xc3\xada_pnoun', 'Dastis_pnoun', 'Z2']
# ['Alfonso_pnoun', 'Mar\xc3\xada_pnoun', 'Dastis_pnoun', 'Quecedo_pnoun', 'Z2']
# ['Alfoz_pnoun', 'de_pnoun', 'Bricia_pnoun', 'Z2']
# ['Alfoz_pnoun', 'de_pnoun', 'Lloredo_pnoun', 'Z2']
# ['Alfoz_pnoun', 'de_pnoun', 'Quintanadue\xc3\xb1as_pnoun', 'Z2']
# ['Alfoz_pnoun', 'de_pnoun', 'Santa_pnoun', 'Gadea_pnoun', 'Z2']
# ['Alfredo_pnoun', 'Carneros_pnoun', 'Z2']
# ['Alfredo_pnoun', 'Carneros_pnoun', 'Beamud_pnoun', 'Z2']
# ['Algar_pnoun', 'de_pnoun', 'Mesa_pnoun', 'Z2']
# ['Algar_pnoun', 'de_pnoun', 'Palancia_pnoun', 'Z2']
# ['Algimia_pnoun', 'de_pnoun', 'Alfara_pnoun', 'Z2']
# ['Algimia_pnoun', 'de_pnoun', 'Almonacid_pnoun', 'Z2']
# ['Alhama_pnoun', 'de_pnoun', 'Almer\xc3\xada_pnoun', 'Z2']
# ['Alhama_pnoun', 'de_pnoun', 'Arag\xc3\xb3n_pnoun', 'Z2']
# ['Alhama_pnoun', 'de_pnoun', 'Granada_pnoun', 'Z2']
# ['Alhama_pnoun', 'de_pnoun', 'Murcia_pnoun', 'Z2']
# ['Alhaur\xc3\xadn_pnoun', 'de_pnoun', 'la_pnoun', 'Torre_pnoun', 'Z2']
# ['Alhaur\xc3\xadn_pnoun', 'el_pnoun', 'Grande_pnoun', 'Z2']
# ['Alice_pnoun', 'Mat\xc4\x9bjkov\xc3\xa1_pnoun', 'Z2']
# ['Alic\xc3\xban_pnoun', 'de_pnoun', 'Ortega_pnoun', 'Z2']
# ['Alija_pnoun', 'del_pnoun', 'Infantado_pnoun', 'Z2']
# ['Aliuska_pnoun', 'L\xc3\xb3pez_pnoun', 'Z2']
# ['alma_noun', 'que_pron', 'se_pron', 'la_pron', 'lleva_fw', 'el_art', 'diablo_noun', 'T1']
# ['Almad\xc3\xa9n_pnoun', 'de_pnoun', 'la_pnoun', 'Plata_pnoun', 'Z2']
# ['Almaraz_pnoun', 'de_pnoun', 'Duero_pnoun', 'Z2']
# ['Almarza_pnoun', 'de_pnoun', 'Cameros_pnoun', 'Z2']
# ['Almeida_pnoun', 'de_pnoun', 'Sayago_pnoun', 'Z2']
# ['Almenar_pnoun', 'de_pnoun', 'Soria_pnoun', 'Z2']
# ['Almenara_pnoun', 'de_pnoun', 'Adaja_pnoun', 'Z2']
# ['Almenara_pnoun', 'de_pnoun', 'Tormes_pnoun', 'Z2']
# ['Almendral_pnoun', 'de_pnoun', 'la_pnoun', 'Ca\xc3\xb1ada_pnoun', 'Z2']
# ['Almod\xc3\xb3var_pnoun', 'del_pnoun', 'Campo_pnoun', 'Z2']
# ['Almod\xc3\xb3var_pnoun', 'del_pnoun', 'Pinar_pnoun', 'Z2']
# ['Almod\xc3\xb3var_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Almonacid_pnoun', 'de_pnoun', 'la_pnoun', 'Cuba_pnoun', 'Z2']
# ['Almonacid_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Almonacid_pnoun', 'de_pnoun', 'Toledo_pnoun', 'Z2']
# ['Almonacid_pnoun', 'de_pnoun', 'Zorita_pnoun', 'Z2']
# ['Almonacid_pnoun', 'del_pnoun', 'Marquesado_pnoun', 'Z2']
# ['Almonaster_pnoun', 'la_pnoun', 'Real_pnoun', 'Z2']
# ['Almudena_pnoun', 'Cid_pnoun', 'Z2']
# ['Almudena_pnoun', 'Cid_pnoun', 'Tostado_pnoun', 'Z2']
# ['Almudena_pnoun', 'Gallardo_pnoun', 'Z2']
# ['Almunia_pnoun', 'de_pnoun', 'San_pnoun', 'Juan_pnoun', 'Z2']
# ['Al\xc3\xb2s_pnoun', 'de_pnoun', 'Balaguer_pnoun', 'Z2']
# ['Alpujarra_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Alquer\xc3\xadas_pnoun', 'del_pnoun', 'Ni\xc3\xb1o_pnoun', 'Perdido_pnoun', 'Z2']
# ['Alt_pnoun', '\xc3\x80neu_pnoun', 'Z2']
# ['\xc3\x81lvaro_pnoun', 'de_pnoun', 'Figueroa_pnoun', 'Z2']
# ['\xc3\x81lvaro_pnoun', 'Fern\xc3\xa1ndez_pnoun', 'Z2']
# ['\xc3\x81lvaro_pnoun', 'Mart\xc3\xadn_pnoun', 'Z2']
# ['\xc3\x81lvaro_pnoun', 'Nadal_pnoun', 'Z2']
# ['\xc3\x81lvaro_pnoun', 'Nadal_pnoun', 'Belda_pnoun', 'Z2']
# ['\xc3\x81lvaro_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Z2']
# ['\xc3\x81lvaro_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Melero_pnoun', 'Z2']
# ['Amaya_pnoun', 'Valdemoro_pnoun', 'Z2']
# ['Amaya_pnoun', 'Valdemoro_pnoun', 'Madariaga_pnoun', 'Z2']
# ['Amayuelas_pnoun', 'de_pnoun', 'Arriba_pnoun', 'Z2']
# ['Am\xc3\xa9scoa_pnoun', 'Baja_pnoun', 'Z2']
# ['Ana_pnoun', 'Bel\xc3\xa9n_pnoun', 'Palomo_pnoun', 'Z2']
# ['Ana_pnoun', 'Burgos_pnoun', 'Z2']
# ['Ana_pnoun', 'Burgos_pnoun', 'Acu\xc3\xb1a_pnoun', 'Z2']
# ['Ana_pnoun', 'Carrascosa_pnoun', 'Z2']
# ['Ana_pnoun', 'Carrascosa_pnoun', 'Zaragoza_pnoun', 'Z2']
# ['Ana_pnoun', 'Isabel_pnoun', 'Medina_pnoun', 'Z2']
# ['Ana_pnoun', 'Isabel_pnoun', 'Medina_pnoun', 'Garrigues_pnoun', 'Z2']
# ['Ana_pnoun', 'Mar\xc3\xada_pnoun', 'Pastor_pnoun', 'Juli\xc3\xa1n_pnoun', 'Z2']
# ['Ana_pnoun', 'Mar\xc3\xada_pnoun', 'Pelaz_pnoun', 'Z2']
# ['Ana_pnoun', 'Mar\xc3\xada_pnoun', 'Pelaz_pnoun', 'Mota_pnoun', 'Z2']
# ['Ana_pnoun', 'Mato_pnoun', 'Z2']
# ['Ana_pnoun', 'Mato_pnoun', 'Adrover_pnoun', 'Z2']
# ['Ana_pnoun', 'Pastor_pnoun', 'Z2']
# ['Ana_pnoun', 'Raquel_pnoun', 'P\xc3\xa9rez_pnoun', 'Z2']
# ['Anabel_pnoun', 'Medina_pnoun', 'Z2']
# ['Anastasia_pnoun', 'Ana_pnoun', 'Montero_pnoun', 'Z2']
# ['Anaya_pnoun', 'de_pnoun', 'Alba_pnoun', 'Z2']
# ['ancha_adj', 'es_verb', 'Castilla_noun', 'X1', 'A1.1.1']
# ['anda_fw', 'manga_noun', 'por_prep', 'hombro_noun', 'A4']
# ['Ander_pnoun', 'Elosegui_pnoun', 'Z2']
# ['Ander_pnoun', 'Elosegui_pnoun', 'Alca\xc3\xadn_pnoun', 'Z2']
# ['Andrea_pnoun', 'Barn\xc3\xb3_pnoun', 'Z2']
# ['Andrea_pnoun', 'Fuentes_pnoun', 'Z2']
# ['Andrea_pnoun', 'Fuentes_pnoun', 'Fache_pnoun', 'Z2']
# ['Andrea_pnoun', 'Fuentes_pnoun', 'Fache*_pnoun', 'Z2']
# ['Andr\xc3\xa9s_pnoun', 'Mata_pnoun', 'Z2']
# ['Andr\xc3\xa9s_pnoun', 'Mata_pnoun', 'P\xc3\xa9rez_pnoun', 'Z2']
# ['\xc3\x81ngel_pnoun', 'David_pnoun', 'Z2']
# ['\xc3\x81ngel_pnoun', 'David_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Z2']
# ['\xc3\x81ngel_pnoun', 'David_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Garc\xc3\xada_pnoun', 'Z2']
# ['\xc3\x81ngel_pnoun', 'Luis_pnoun', 'Andreo_pnoun', 'Z2']
# ['\xc3\x81ngel_pnoun', 'Luis_pnoun', 'Andreo_pnoun', 'Gab\xc3\xa1n_pnoun', 'Z2']
# ['\xc3\x81ngela_pnoun', 'San_pnoun', 'Juan_pnoun', 'Z2']
# ['\xc3\x81ngela_pnoun', 'San_pnoun', 'Juan_pnoun', 'Cisneros_pnoun', 'Z2']
# ['Anna_pnoun', 'Monta\xc3\xb1ana_pnoun', 'Z2']
# ['Anna_pnoun', 'Monta\xc3\xb1ana_pnoun', 'Gimeno_pnoun', 'Z2']
# ['Anna_pnoun', 'Sanch\xc3\xads_pnoun', 'Z2']
# ['Anna_pnoun', 'Sanch\xc3\xads_pnoun', 'Chafer_pnoun', 'Z2']
# ['A\xc3\xb1\xc3\xb3n_pnoun', 'de_pnoun', 'Moncayo_pnoun', 'Z2']
# ['A\xc3\xb1over_pnoun', 'de_pnoun', 'Tajo_pnoun', 'Z2']
# ['A\xc3\xb1over_pnoun', 'de_pnoun', 'Tormes_pnoun', 'Z2']
# ['Anquela_pnoun', 'del_pnoun', 'Ducado_pnoun', 'Z2']
# ['Anquela_pnoun', 'del_pnoun', 'Pedregal_pnoun', 'Z2']
# ['Antas_pnoun', 'de_pnoun', 'Ulla_pnoun', 'Z2']
# ['Antigua_pnoun', 'Rep\xc3\xbablica_pnoun', 'Yugoslava_pnoun', 'de_pnoun', 'Macedonia_pnoun', 'Z2']
# ['Antigua_pnoun', 'y_pnoun', 'Barbuda_pnoun', 'Z2']
# ['Ant\xc3\xb3n_pnoun', 'Paz_pnoun', 'Z2']
# ['Ant\xc3\xb3n_pnoun', 'Paz_pnoun', 'Blanco_pnoun', 'Z2']
# ['Antoni_pnoun', 'Pena_pnoun', 'Z2']
# ['Antonio_pnoun', 'Aguilar_pnoun', 'y_pnoun', 'Correa_pnoun', 'Z2']
# ['Antonio_pnoun', 'Carlos_pnoun', 'Ortega_pnoun', 'Z2']
# ['Antonio_pnoun', 'Jim\xc3\xa9nez_pnoun', 'Z2']
# ['Antonio_pnoun', 'Manuel_pnoun', 'Reina_pnoun', 'Z2']
# ['Antonio_pnoun', 'Manuel_pnoun', 'Reina_pnoun', 'Ballesteros_pnoun', 'Z2']
# ['Antonio_pnoun', 'Maura_pnoun', 'Z2']
# ['Antonio_pnoun', 'Miguel_pnoun', 'Z2']
# ['Antonio_pnoun', 'Miguel_pnoun', 'Parra_pnoun', 'Z2']
# ['Antonio_pnoun', 'Reina_pnoun', 'Ballesteros_pnoun', 'Z2']
# ['Antonio_pnoun', 'Tauler_pnoun', 'Z2']
# ['Antonio_pnoun', 'Tauler_pnoun', 'Llull_pnoun', 'Z2']
# ['apretar_verb', 'el_art', 'zapato_noun', 'X2.2']
# ['Arabayona_pnoun', 'de_pnoun', 'M\xc3\xb3gica_pnoun', 'Z2']
# ['Arabia_pnoun', 'Saud\xc3\xad_pnoun', 'Z2']
# ['Arabia_pnoun', 'Saudita_pnoun', 'Z2']
# ['Araceli_pnoun', 'Navarro_pnoun', 'Z2']
# ['Araceli_pnoun', 'Navarro_pnoun', 'Laso_pnoun', 'Z2']
# ['Arag\xc3\xbc\xc3\xa9s_pnoun', 'del_pnoun', 'Puerto_pnoun', 'Z2']
# ['Aranda_pnoun', 'de_pnoun', 'Duero_pnoun', 'Z2']
# ['Aranda_pnoun', 'de_pnoun', 'Moncayo_pnoun', 'Z2']
# ['Arandilla_pnoun', 'del_pnoun', 'Arroyo_pnoun', 'Z2']
# ['Arantxa_pnoun', 'Ramos_pnoun', 'Z2']
# ['Arantxa_pnoun', 'Ramos_pnoun', 'Plasencia_pnoun', 'Z2']
# ['Arantxa_pnoun', 'S\xc3\xa1nchez_pnoun', 'Vicario_pnoun', 'Z2']
# ['Aras_pnoun', 'de_pnoun', 'los_pnoun', 'Olmos_pnoun', 'Z2']
# ['Arauzo_pnoun', 'de_pnoun', 'Miel_pnoun', 'Z2']
# ['Arauzo_pnoun', 'de_pnoun', 'Salce_pnoun', 'Z2']
# ['Arauzo_pnoun', 'de_pnoun', 'Torre_pnoun', 'Z2']
# ['Arcos_pnoun', 'de_pnoun', 'Jal\xc3\xb3n_pnoun', 'Z2']
# ['Arcos_pnoun', 'de_pnoun', 'la_pnoun', 'Frontera_pnoun', 'Z2']
# ['Arcos_pnoun', 'de_pnoun', 'la_pnoun', 'Polvorosa_pnoun', 'Z2']
# ['Arcos_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Arcos_pnoun', 'de_pnoun', 'las_pnoun', 'Salinas_pnoun', 'Z2']
# ['Arenales_pnoun', 'de_pnoun', 'San_pnoun', 'Gregorio_pnoun', 'Z2']
# ['Arenas_pnoun', 'de_pnoun', 'Igu\xc3\xb1a_pnoun', 'Z2']
# ['Arenas_pnoun', 'de_pnoun', 'San_pnoun', 'Juan_pnoun', 'Z2']
# ['Arenas_pnoun', 'de_pnoun', 'San_pnoun', 'Pedro_pnoun', 'Z2']
# ['Arenas_pnoun', 'del_pnoun', 'Rey_pnoun', 'Z2']
# ['Arenillas_pnoun', 'de_pnoun', 'Riopisuerga_pnoun', 'Z2']
# ['Arens_pnoun', 'de_pnoun', 'Lled\xc3\xb3_pnoun', 'Z2']
# ['Arenys_pnoun', 'de_pnoun', 'Mar_pnoun', 'Z2']
# ['Arenys_pnoun', 'de_pnoun', 'Munt_pnoun', 'Z2']
# ['Arenzana_pnoun', 'de_pnoun', 'Abajo_pnoun', 'Z2']
# ['Arenzana_pnoun', 'de_pnoun', 'Arriba_pnoun', 'Z2']
# ['Ares_pnoun', 'del_pnoun', 'Maestrat_pnoun', 'Z2']
# ['Arevalillo_pnoun', 'de_pnoun', 'Cega_pnoun', 'Z2']
# ['Ar\xc3\xa9valo_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Argamasilla_pnoun', 'de_pnoun', 'Alba_pnoun', 'Z2']
# ['Argamasilla_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Arganda_pnoun', 'del_pnoun', 'Rey_pnoun', 'Z2']
# ['armar_verb', 'un_art', 'cisco_noun', 'E8', 'A2']
# ['Armu\xc3\xb1a_pnoun', 'de_pnoun', 'Almanzora_pnoun', 'Z2']
# ['Armu\xc3\xb1a_pnoun', 'de_pnoun', 'Taju\xc3\xb1a_pnoun', 'Z2']
# ['Arpad_pnoun', '\xc5\xa0terbik_pnoun', 'Z2']
# ['Arraya_pnoun', 'de_pnoun', 'Oca_pnoun', 'Z2']
# ['arrimar_verb', 'el_art', 'ascua_noun', 'a_prep', 'su_pron', 'sardina_noun', 'S7.1', 'S1.2.2']
# ['Arroba_pnoun', 'de_pnoun', 'los_pnoun', 'Montes_pnoun', 'Z2']
# ['Arroyo_pnoun', 'de_pnoun', 'la_pnoun', 'Encomienda_pnoun', 'Z2']
# ['Arroyo_pnoun', 'de_pnoun', 'la_pnoun', 'Luz_pnoun', 'Z2']
# ['Arroyo_pnoun', 'de_pnoun', 'las_pnoun', 'Fraguas_pnoun', 'Z2']
# ['Arroyo_pnoun', 'de_pnoun', 'San_pnoun', 'Serv\xc3\xa1n_pnoun', 'Z2']
# ['Arroyo_pnoun', 'del_pnoun', 'Ojanco_pnoun', 'Z2']
# ['Arroyomolinos_pnoun', 'de_pnoun', 'la_pnoun', 'Vera_pnoun', 'Z2']
# ['Arroyomolinos_pnoun', 'de_pnoun', 'Le\xc3\xb3n_pnoun', 'Z2']
# ['Artesa_pnoun', 'de_pnoun', 'Lleida_pnoun', 'Z2']
# ['Artesa_pnoun', 'de_pnoun', 'Segre_pnoun', 'Z2']
# ['Arturo_pnoun', 'Casado_pnoun', 'Z2']
# ['Arturo_pnoun', 'Casado_pnoun', 'Alda_pnoun', 'Z2']
# ['Aschwin_pnoun', 'Wildeboer_pnoun', 'Z2']
# ['Asier_pnoun', 'Maeztu_pnoun', 'Z2']
# ['Asier_pnoun', 'Maeztu_pnoun', 'Villabeitia_pnoun', 'Z2']
# ['Atalaya_pnoun', 'del_pnoun', 'Ca\xc3\xb1avate_pnoun', 'Z2']
# ['Atzeneta_pnoun', "D'albaida_pnoun", 'Z2']
# ['Atzeneta_pnoun', 'del_pnoun', 'Maestrat_pnoun', 'Z2']
# ['Ausejo_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Autilla_pnoun', 'del_pnoun', 'Pino_pnoun', 'Z2']
# ['Autillo_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Avellanosa_pnoun', 'de_pnoun', 'Mu\xc3\xb1\xc3\xb3_pnoun', 'Z2']
# ['Avinyonet_pnoun', 'de_pnoun', 'Puigvent\xc3\xb3s_pnoun', 'Z2']
# ['Avinyonet_pnoun', 'del_pnoun', 'Pened\xc3\xa8s_pnoun', 'Z2']
# ['Ayad_pnoun', 'Lamdassem_pnoun', 'Z2']
# ['Ayad_pnoun', 'Lamdassem_pnoun', 'El_pnoun', 'Z2']
# ['Ayad_pnoun', 'Lamdassem_pnoun', 'El_pnoun', 'Mouhcin_pnoun', 'Z2']
# ['Ayo\xc3\xb3_pnoun', 'de_pnoun', 'Vidriales_pnoun', 'Z2']
# ['Aytami_pnoun', 'Ruano_pnoun', 'Z2']
# ['Azuqueca_pnoun', 'de_pnoun', 'Henares_pnoun', 'Z2']
# ['Badia_pnoun', 'del_pnoun', 'Vall\xc3\xa8s_pnoun', 'Z2']
# ['Bahab\xc3\xb3n_pnoun', 'de_pnoun', 'Esgueva_pnoun', 'Z2']
# ['bailar_verb', 'el_art', 'agua_noun', 'S1.1.2', 'S3', 'X9']
# ['Baix_pnoun', 'Pallars_pnoun', 'Z2']
# ['B\xc3\xa1lazs_pnoun', 'Szir\xc3\xa1nyi_pnoun', 'Z2']
# ['Ballesteros_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Balsa_pnoun', 'de_pnoun', 'Ves_pnoun', 'Z2']
# ['Bandar_pnoun', 'Lampung_pnoun', 'Z2']
# ['Ba\xc3\xb1os_pnoun', 'de_pnoun', 'Ebro_pnoun', 'Z2']
# ['Ba\xc3\xb1os_pnoun', 'de_pnoun', 'la_pnoun', 'Encina_pnoun', 'Z2']
# ['Ba\xc3\xb1os_pnoun', 'de_pnoun', 'Molgas_pnoun', 'Z2']
# ['Ba\xc3\xb1os_pnoun', 'de_pnoun', 'Montemayor_pnoun', 'Z2']
# ['Ba\xc3\xb1os_pnoun', 'de_pnoun', 'R\xc3\xado_pnoun', 'Tob\xc3\xada_pnoun', 'Z2']
# ['Ba\xc3\xb1os_pnoun', 'de_pnoun', 'Rioja_pnoun', 'Z2']
# ['Ba\xc3\xb1os_pnoun', 'de_pnoun', 'Tajo_pnoun', 'Z2']
# ['Ba\xc3\xb1os_pnoun', 'de_pnoun', 'Valdearados_pnoun', 'Z2']
# ['Ba\xc3\xb1uelos_pnoun', 'de_pnoun', 'Bureba_pnoun', 'Z2']
# ['Banyeres_pnoun', 'de_pnoun', 'Mariola_pnoun', 'Z2']
# ['Banyeres_pnoun', 'del_pnoun', 'Pened\xc3\xa8s_pnoun', 'Z2']
# ['Baquer\xc3\xadn_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Barajas_pnoun', 'de_pnoun', 'Melo_pnoun', 'Z2']
# ['Barbadillo_pnoun', 'de_pnoun', 'Herreros_pnoun', 'Z2']
# ['Barbadillo_pnoun', 'del_pnoun', 'Mercado_pnoun', 'Z2']
# ['Barbadillo_pnoun', 'del_pnoun', 'Pez_pnoun', 'Z2']
# ['B\xc3\xa1rbara_pnoun', 'Gonz\xc3\xa1lez_pnoun', 'Z2']
# ['B\xc3\xa1rbara_pnoun', 'Gonz\xc3\xa1lez_pnoun', 'Oteiza_pnoun', 'Z2']
# ['B\xc3\xa1rbara_pnoun', 'Malda_pnoun', 'Z2']
# ['B\xc3\xa1rbara_pnoun', 'Mald\xc3\xa1_pnoun', 'Z2']
# ['B\xc3\xa1rbara_pnoun', 'Mald\xc3\xa1_pnoun', 'Salinas_pnoun', 'Z2']
# ['Barber\xc3\xa0_pnoun', 'de_pnoun', 'la_pnoun', 'Conca_pnoun', 'Z2']
# ['Barber\xc3\xa0_pnoun', 'del_pnoun', 'Vall\xc3\xa8s_pnoun', 'Z2']
# ['B\xc3\xa1rcena_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['B\xc3\xa1rcena_pnoun', 'de_pnoun', 'Cicero_pnoun', 'Z2']
# ['B\xc3\xa1rcena_pnoun', 'de_pnoun', 'Pie_pnoun', 'de_pnoun', 'Concha_pnoun', 'Z2']
# ['Barch\xc3\xadn_pnoun', 'del_pnoun', 'Hoyo_pnoun', 'Z2']
# ['Barcial_pnoun', 'de_pnoun', 'la_pnoun', 'Loma_pnoun', 'Z2']
# ['Barcial_pnoun', 'del_pnoun', 'Barco_pnoun', 'Z2']
# ['Barrio_pnoun', 'de_pnoun', 'Mu\xc3\xb1\xc3\xb3_pnoun', 'Z2']
# ['Barrios_pnoun', 'de_pnoun', 'Colina_pnoun', 'Z2']
# ['Barruelo_pnoun', 'de_pnoun', 'Santull\xc3\xa1n_pnoun', 'Z2']
# ['Barruelo_pnoun', 'del_pnoun', 'Valle_pnoun', 'Z2']
# ['Basconcillos_pnoun', 'del_pnoun', 'Tozo_pnoun', 'Z2']
# ['B\xc3\xa1scones_pnoun', 'de_pnoun', 'Ojeda_pnoun', 'Z2']
# ['Bascu\xc3\xb1ana_pnoun', 'de_pnoun', 'San_pnoun', 'Pedro_pnoun', 'Z2']
# ['batir_verb', 'el_art', 'cobre_noun', 'S1.2.5']
# ['Bayubas_pnoun', 'de_pnoun', 'Abajo_pnoun', 'Z2']
# ['Bayubas_pnoun', 'de_pnoun', 'Arriba_pnoun', 'Z2']
# ['Beas_pnoun', 'de_pnoun', 'Granada_pnoun', 'Z2']
# ['Beas_pnoun', 'de_pnoun', 'Guadix_pnoun', 'Z2']
# ['Beas_pnoun', 'de_pnoun', 'Segura_pnoun', 'Z2']
# ['Beatriz_pnoun', 'Ferrer-Salat_pnoun', 'Z2']
# ['Beatriz_pnoun', 'Manch\xc3\xb3n_pnoun', 'Z2']
# ['Beatriz_pnoun', 'Manch\xc3\xb3n_pnoun', 'Portillo_pnoun', 'Z2']
# ['Beatriz_pnoun', 'Pascual_pnoun', 'Z2']
# ['Beatriz_pnoun', 'Pascual_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Z2']
# ['Beatriz_pnoun', 'Ros_pnoun', 'Z2']
# ['beber_verb', 'como_conj', 'un_num', 'cosaco_noun', 'E6', 'A5', 'O1.2']
# ['Becerril_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Becerril_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Becilla_pnoun', 'de_pnoun', 'Valderaduey_pnoun', 'Z2']
# ['Bedmar_pnoun', 'y_pnoun', 'Garc\xc3\xadez_pnoun', 'Z2']
# ['Bego\xc3\xb1a_pnoun', 'Garc\xc3\xada_pnoun', 'Z2']
# ['Bell-Lloc_pnoun', "D'urgell_pnoun", 'Z2']
# ['Bellcaire_pnoun', "D'empord\xc3\xa0_pnoun", 'Z2']
# ['Bellcaire_pnoun', "D'urgell_pnoun", 'Z2']
# ['Bellmunt_pnoun', "D'urgell_pnoun", 'Z2']
# ['Bellmunt_pnoun', 'del_pnoun', 'Priorat_pnoun', 'Z2']
# ['Bellver_pnoun', 'de_pnoun', 'Cerdanya_pnoun', 'Z2']
# ['B\xc3\xa9lmez_pnoun', 'de_pnoun', 'la_pnoun', 'Moraleda_pnoun', 'Z2']
# ['Belmonte_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Belmonte_pnoun', 'de_pnoun', 'Graci\xc3\xa1n_pnoun', 'Z2']
# ['Belmonte_pnoun', 'de_pnoun', 'Miranda_pnoun', 'Z2']
# ['Belmonte_pnoun', 'de_pnoun', 'San_pnoun', 'Jos\xc3\xa9_pnoun', 'Z2']
# ['Belmonte_pnoun', 'de_pnoun', 'Tajo_pnoun', 'Z2']
# ['Belo_pnoun', 'Horizonte_pnoun', 'Z2']
# ['Belver_pnoun', 'de_pnoun', 'Cinca_pnoun', 'Z2']
# ['Belver_pnoun', 'de_pnoun', 'los_pnoun', 'Montes_pnoun', 'Z2']
# ['Belv\xc3\xads_pnoun', 'de_pnoun', 'la_pnoun', 'Jara_pnoun', 'Z2']
# ['Belv\xc3\xads_pnoun', 'de_pnoun', 'Monroy_pnoun', 'Z2']
# ['Benal\xc3\xbaa_pnoun', 'de_pnoun', 'las_pnoun', 'Villas_pnoun', 'Z2']
# ['Benalup-Casas_pnoun', 'Viejas_pnoun', 'Z2']
# ['Benavent_pnoun', 'de_pnoun', 'Segri\xc3\xa0_pnoun', 'Z2']
# ['Benicull_pnoun', 'de_pnoun', 'X\xc3\xbaquer_pnoun', 'Z2']
# ['Benifair\xc3\xb3_pnoun', 'de_pnoun', 'la_pnoun', 'Valldigna_pnoun', 'Z2']
# ['Benifair\xc3\xb3_pnoun', 'de_pnoun', 'Les_pnoun', 'Valls_pnoun', 'Z2']
# ['Benin_pnoun', 'City_pnoun', 'Z2']
# ['Benjam\xc3\xadn_pnoun', 'S\xc3\xa1nchez_pnoun', 'Z2']
# ['Benjam\xc3\xadn_pnoun', 'S\xc3\xa1nchez_pnoun', 'Bermejo_pnoun', 'Z2']
# ['Benquerencia_pnoun', 'de_pnoun', 'la_pnoun', 'Serena_pnoun', 'Z2']
# ['Bercial_pnoun', 'de_pnoun', 'Zapardiel_pnoun', 'Z2']
# ['Bercianos_pnoun', 'del_pnoun', 'P\xc3\xa1ramo_pnoun', 'Z2']
# ['Bercianos_pnoun', 'del_pnoun', 'Real_pnoun', 'Camino_pnoun', 'Z2']
# ['Bergasillas_pnoun', 'Bajera_pnoun', 'Z2']
# ['Berlanga_pnoun', 'de_pnoun', 'Duero_pnoun', 'Z2']
# ['Berlanga_pnoun', 'del_pnoun', 'Bierzo_pnoun', 'Z2']
# ['Berlangas_pnoun', 'de_pnoun', 'Roa_pnoun', 'Z2']
# ['Bermillo_pnoun', 'de_pnoun', 'Sayago_pnoun', 'Z2']
# ['Bernardino_pnoun', 'Herrera_pnoun', 'Z2']
# ['Bernardo_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Z2']
# ['Bernardo_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Arias_pnoun', 'Z2']
# ['Bernuy_pnoun', 'de_pnoun', 'Porreros_pnoun', 'Z2']
# ['Berrocal_pnoun', 'de_pnoun', 'Huebra_pnoun', 'Z2']
# ['Berrocal_pnoun', 'de_pnoun', 'Salvatierra_pnoun', 'Z2']
# ['Berrocalejo_pnoun', 'de_pnoun', 'Aragona_pnoun', 'Z2']
# ['Berta_pnoun', 'Castells_pnoun', 'Z2']
# ['Berta_pnoun', 'Castells_pnoun', 'Franco_pnoun', 'Z2']
# ['Berzosa_pnoun', 'de_pnoun', 'Bureba_pnoun', 'Z2']
# ['Berzosa_pnoun', 'del_pnoun', 'Lozoya_pnoun', 'Z2']
# ['Bigues_pnoun', 'I_pnoun', 'Riells_pnoun', 'Z2']
# ['Blanca_pnoun', 'Manch\xc3\xb3n_pnoun', 'Z2']
# ['Blasconu\xc3\xb1o_pnoun', 'de_pnoun', 'Matacabras_pnoun', 'Z2']
# ['Blecua_pnoun', 'y_pnoun', 'Torres_pnoun', 'Z2']
# ['Boada_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Boadella_pnoun', 'I_pnoun', 'Les_pnoun', 'Escaules_pnoun', 'Z2']
# ['Boadilla_pnoun', 'de_pnoun', 'Rioseco_pnoun', 'Z2']
# ['Boadilla_pnoun', 'del_pnoun', 'Camino_pnoun', 'Z2']
# ['Boadilla_pnoun', 'del_pnoun', 'Monte_pnoun', 'Z2']
# ['Bobadilla_pnoun', 'del_pnoun', 'Campo_pnoun', 'Z2']
# ['Boca_pnoun', 'de_pnoun', 'Hu\xc3\xa9rgano_pnoun', 'Z2']
# ['Bocos_pnoun', 'de_pnoun', 'Duero_pnoun', 'Z2']
# ['Bodonal_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Bohonal_pnoun', 'de_pnoun', 'Ibor_pnoun', 'Z2']
# ['Bola\xc3\xb1os_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Bola\xc3\xb1os_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Bollullos_pnoun', 'de_pnoun', 'la_pnoun', 'Mitaci\xc3\xb3n_pnoun', 'Z2']
# ['Bollullos_pnoun', 'Par_pnoun', 'del_pnoun', 'Condado_pnoun', 'Z2']
# ['Bonilla_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Bonrep\xc3\xb2s_pnoun', 'I_pnoun', 'Mirambell_pnoun', 'Z2']
# ['Borja_pnoun', 'Iradier_pnoun', 'Z2']
# ['Borja_pnoun', 'Iradier_pnoun', 'Aguirrez\xc3\xa1bal_pnoun', 'Z2']
# ['Borja_pnoun', 'Vivas_pnoun', 'Z2']
# ['Bosnia_pnoun', 'y_pnoun', 'Herzegovina_pnoun', 'Z2']
# ['B\xc3\xb3veda_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Almar_pnoun', 'Z2']
# ['Brahojos_pnoun', 'de_pnoun', 'Medina_pnoun', 'Z2']
# ['Brea_pnoun', 'de_pnoun', 'Arag\xc3\xb3n_pnoun', 'Z2']
# ['Brea_pnoun', 'de_pnoun', 'Tajo_pnoun', 'Z2']
# ['Bre\xc3\xb1a_pnoun', 'Alta_pnoun', 'Z2']
# ['Bre\xc3\xb1a_pnoun', 'Baja_pnoun', 'Z2']
# ['Brenton_pnoun', 'Cabello_pnoun', 'Z2']
# ['Brenton_pnoun', 'Cabello_pnoun', 'Forns_pnoun', 'Z2']
# ['Brieva_pnoun', 'de_pnoun', 'Cameros_pnoun', 'Z2']
# ['Brigitte_pnoun', 'Yag\xc3\xbce_pnoun', 'Z2']
# ['Brime_pnoun', 'de_pnoun', 'Sog_pnoun', 'Z2']
# ['Brime_pnoun', 'de_pnoun', 'Urz_pnoun', 'Z2']
# ['Brunei_pnoun', 'Darussalam_pnoun', 'Z2']
# ['Buenache_pnoun', 'de_pnoun', 'Alarc\xc3\xb3n_pnoun', 'Z2']
# ['Buenache_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Buenavista_pnoun', 'de_pnoun', 'Valdavia_pnoun', 'Z2']
# ['Buenavista_pnoun', 'del_pnoun', 'Norte_pnoun', 'Z2']
# ['Buenos_pnoun', 'Aires_pnoun', 'Z2']
# ['Buitrago_pnoun', 'del_pnoun', 'Lozoya_pnoun', 'Z2']
# ['Burganes_pnoun', 'de_pnoun', 'Valverde_pnoun', 'Z2']
# ['Burgo_pnoun', 'de_pnoun', 'Osma-Ciudad_pnoun', 'de_pnoun', 'Osma_pnoun', 'Z2']
# ['Burguillos_pnoun', 'de_pnoun', 'Toledo_pnoun', 'Z2']
# ['Burguillos_pnoun', 'del_pnoun', 'Cerro_pnoun', 'Z2']
# ['Burkina_pnoun', 'Faso_pnoun', 'Z2']
# ['Bustillo_pnoun', 'de_pnoun', 'Chaves_pnoun', 'Z2']
# ['Bustillo_pnoun', 'de_pnoun', 'la_pnoun', 'Vega_pnoun', 'Z2']
# ['Bustillo_pnoun', 'del_pnoun', 'Oro_pnoun', 'Z2']
# ['Bustillo_pnoun', 'del_pnoun', 'P\xc3\xa1ramo_pnoun', 'Z2']
# ['Bustillo_pnoun', 'del_pnoun', 'P\xc3\xa1ramo_pnoun', 'de_pnoun', 'Carri\xc3\xb3n_pnoun', 'Z2']
# ['Busto_pnoun', 'de_pnoun', 'Bureba_pnoun', 'Z2']
# ['Cabana_pnoun', 'de_pnoun', 'Berganti\xc3\xb1os_pnoun', 'Z2']
# ['Caba\xc3\xb1as_pnoun', 'de_pnoun', 'Ebro_pnoun', 'Z2']
# ['Caba\xc3\xb1as_pnoun', 'de_pnoun', 'la_pnoun', 'Sagra_pnoun', 'Z2']
# ['Caba\xc3\xb1as_pnoun', 'de_pnoun', 'Polendos_pnoun', 'Z2']
# ['Caba\xc3\xb1as_pnoun', 'de_pnoun', 'Sayago_pnoun', 'Z2']
# ['Caba\xc3\xb1as_pnoun', 'de_pnoun', 'Yepes_pnoun', 'Z2']
# ['Caba\xc3\xb1as_pnoun', 'del_pnoun', 'Castillo_pnoun', 'Z2']
# ['Caba\xc3\xb1as_pnoun', 'Raras_pnoun', 'Z2']
# ['Caba\xc3\xb1es_pnoun', 'de_pnoun', 'Esgueva_pnoun', 'Z2']
# ['Cabanillas_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Cabanillas_pnoun', 'del_pnoun', 'Campo_pnoun', 'Z2']
# ['Cabeza_pnoun', 'del_pnoun', 'Buey_pnoun', 'Z2']
# ['Cabeza_pnoun', 'del_pnoun', 'Caballo_pnoun', 'Z2']
# ['Cabeza_pnoun', 'la_pnoun', 'Vaca_pnoun', 'Z2']
# ['Cabezabellosa_pnoun', 'de_pnoun', 'la_pnoun', 'Calzada_pnoun', 'Z2']
# ['Cabezarrubias_pnoun', 'del_pnoun', 'Puerto_pnoun', 'Z2']
# ['Cabezas_pnoun', 'de_pnoun', 'Alambre_pnoun', 'Z2']
# ['Cabezas_pnoun', 'del_pnoun', 'Pozo_pnoun', 'Z2']
# ['Cabezas_pnoun', 'del_pnoun', 'Villar_pnoun', 'Z2']
# ['Cabezas_pnoun', 'Rubias_pnoun', 'Z2']
# ['Cabez\xc3\xb3n_pnoun', 'de_pnoun', 'Cameros_pnoun', 'Z2']
# ['Cabez\xc3\xb3n_pnoun', 'de_pnoun', 'la_pnoun', 'Sal_pnoun', 'Z2']
# ['Cabez\xc3\xb3n_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Cabez\xc3\xb3n_pnoun', 'de_pnoun', 'Li\xc3\xa9bana_pnoun', 'Z2']
# ['Cabez\xc3\xb3n_pnoun', 'de_pnoun', 'Pisuerga_pnoun', 'Z2']
# ['Cabez\xc3\xb3n_pnoun', 'de_pnoun', 'Valderaduey_pnoun', 'Z2']
# ['Cabezuela_pnoun', 'del_pnoun', 'Valle_pnoun', 'Z2']
# ['Cabo_pnoun', 'Verde_pnoun', 'Z2']
# ['Cabra_pnoun', 'de_pnoun', 'Mora_pnoun', 'Z2']
# ['Cabra_pnoun', 'del_pnoun', 'Camp_pnoun', 'Z2']
# ['Cabra_pnoun', 'del_pnoun', 'Santo_pnoun', 'Cristo_pnoun', 'Z2']
# ['Cabrejas_pnoun', 'del_pnoun', 'Campo_pnoun', 'Z2']
# ['Cabrejas_pnoun', 'del_pnoun', 'Pinar_pnoun', 'Z2']
# ['Cabrera_pnoun', "D'anoia_pnoun", 'Z2']
# ['Cabrera_pnoun', 'de_pnoun', 'Mar_pnoun', 'Z2']
# ['Cabreros_pnoun', 'del_pnoun', 'Monte_pnoun', 'Z2']
# ['Cabreros_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Cadalso_pnoun', 'de_pnoun', 'los_pnoun', 'Vidrios_pnoun', 'Z2']
# ['caer_verb', 'el_art', 'alma_noun', 'a_prep', 'los_art', 'pies_noun', 'E4', 'E6']
# ['Calabazas_pnoun', 'de_pnoun', 'Fuentidue\xc3\xb1a_pnoun', 'Z2']
# ['Calahorra_pnoun', 'de_pnoun', 'Boedo_pnoun', 'Z2']
# ['Caldas_pnoun', 'de_pnoun', 'Reis_pnoun', 'Z2']
# ['Caldes_pnoun', "D'estrac_pnoun", 'Z2']
# ['Caldes_pnoun', 'de_pnoun', 'Malavella_pnoun', 'Z2']
# ['Caldes_pnoun', 'de_pnoun', 'Montbui_pnoun', 'Z2']
# ['Calera_pnoun', 'de_pnoun', 'Le\xc3\xb3n_pnoun', 'Z2']
# ['Calera_pnoun', 'y_pnoun', 'Chozas_pnoun', 'Z2']
# ['Callosa_pnoun', "D'en_pnoun", 'Sarri\xc3\xa0_pnoun', 'Z2']
# ['Callosa_pnoun', 'de_pnoun', 'Segura_pnoun', 'Z2']
# ['Calonge_pnoun', 'de_pnoun', 'Segarra_pnoun', 'Z2']
# ['Calvarrasa_pnoun', 'de_pnoun', 'Abajo_pnoun', 'Z2']
# ['Calvarrasa_pnoun', 'de_pnoun', 'Arriba_pnoun', 'Z2']
# ['Calvos_pnoun', 'de_pnoun', 'Rand\xc3\xadn_pnoun', 'Z2']
# ['Calzada_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Calzada_pnoun', 'de_pnoun', 'Don_pnoun', 'Diego_pnoun', 'Z2']
# ['Calzada_pnoun', 'de_pnoun', 'los_pnoun', 'Molinos_pnoun', 'Z2']
# ['Calzada_pnoun', 'de_pnoun', 'Oropesa_pnoun', 'Z2']
# ['Calzada_pnoun', 'de_pnoun', 'Valdunciel_pnoun', 'Z2']
# ['Calzada_pnoun', 'del_pnoun', 'Coto_pnoun', 'Z2']
# ['Calzadilla_pnoun', 'de_pnoun', 'los_pnoun', 'Barros_pnoun', 'Z2']
# ['Calzadilla_pnoun', 'de_pnoun', 'Tera_pnoun', 'Z2']
# ['Camarena_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Camarma_pnoun', 'de_pnoun', 'Esteruelas_pnoun', 'Z2']
# ['Camarzana_pnoun', 'de_pnoun', 'Tera_pnoun', 'Z2']
# ['cambiar_verb', 'el_art', 'agua_noun', 'a_prep', 'las_art', 'aceitunas_noun', 'S1.2', 'A1.1.1']
# ['Camp_pnoun', 'de_pnoun', 'Mirra_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Altobuey_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Arag\xc3\xb3n_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Aranda_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Arenas_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Azaba_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Deleitosa_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Due\xc3\xb1as_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Llerena_pnoun', 'Z2']
# ['Campillo_pnoun', 'de_pnoun', 'Ranas_pnoun', 'Z2']
# ['Campo_pnoun', 'de_pnoun', 'Criptana_pnoun', 'Z2']
# ['Campo_pnoun', 'de_pnoun', 'San_pnoun', 'Pedro_pnoun', 'Z2']
# ['Campo_pnoun', 'de_pnoun', 'Villavidel_pnoun', 'Z2']
# ['Campo_pnoun', 'Lameiro_pnoun', 'Z2']
# ['Campo_pnoun', 'Lugar_pnoun', 'Z2']
# ['Campo_pnoun', 'Real_pnoun', 'Z2']
# ['Campoo_pnoun', 'de_pnoun', 'Enmedio_pnoun', 'Z2']
# ['Campoo_pnoun', 'de_pnoun', 'Yuso_pnoun', 'Z2']
# ['Campos_pnoun', 'del_pnoun', 'Para\xc3\xadso_pnoun', 'Z2']
# ['Campos_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Can_pnoun', 'Tho_pnoun', 'Z2']
# ['Ca\xc3\xb1ada_pnoun', 'de_pnoun', 'Benatanduz_pnoun', 'Z2']
# ['Ca\xc3\xb1ada_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Ca\xc3\xb1ada_pnoun', 'del_pnoun', 'Hoyo_pnoun', 'Z2']
# ['Ca\xc3\xb1ada_pnoun', 'Juncosa_pnoun', 'Z2']
# ['Ca\xc3\xb1ada_pnoun', 'Rosal_pnoun', 'Z2']
# ['Ca\xc3\xb1ada_pnoun', 'Vellida_pnoun', 'Z2']
# ['Canal_pnoun', 'de_pnoun', 'Berd\xc3\xban_pnoun', 'Z2']
# ['Canalejas_pnoun', 'de_pnoun', 'Pe\xc3\xb1afiel_pnoun', 'Z2']
# ['Canalejas_pnoun', 'del_pnoun', 'Arroyo_pnoun', 'Z2']
# ['Canales_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Ca\xc3\xb1averal_pnoun', 'de_pnoun', 'Le\xc3\xb3n_pnoun', 'Z2']
# ['Canet_pnoun', "D'adri_pnoun", 'Z2']
# ['Canet_pnoun', "D'en_pnoun", 'Berenguer_pnoun', 'Z2']
# ['Canet_pnoun', 'de_pnoun', 'Mar_pnoun', 'Z2']
# ['Canet_pnoun', 'Lo_pnoun', 'Roig_pnoun', 'Z2']
# ['Ca\xc3\xb1ete_pnoun', 'de_pnoun', 'las_pnoun', 'Torres_pnoun', 'Z2']
# ['Ca\xc3\xb1ete_pnoun', 'la_pnoun', 'Real_pnoun', 'Z2']
# ['Cangas_pnoun', 'de_pnoun', 'On\xc3\xads_pnoun', 'Z2']
# ['Cangas_pnoun', 'del_pnoun', 'Narcea_pnoun', 'Z2']
# ['Canicosa_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Canillas_pnoun', 'de_pnoun', 'Abajo_pnoun', 'Z2']
# ['Canillas_pnoun', 'de_pnoun', 'Aceituno_pnoun', 'Z2']
# ['Canillas_pnoun', 'de_pnoun', 'Albaida_pnoun', 'Z2']
# ['Canillas_pnoun', 'de_pnoun', 'Esgueva_pnoun', 'Z2']
# ['Canillas_pnoun', 'de_pnoun', 'R\xc3\xado_pnoun', 'Tuerto_pnoun', 'Z2']
# ['Ca\xc3\xb1izar_pnoun', 'del_pnoun', 'Olivar_pnoun', 'Z2']
# ['C\xc3\xa0noves_pnoun', 'I_pnoun', 'Samal\xc3\xbas_pnoun', 'Z2']
# ['Caracuel_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Caravaca_pnoun', 'de_pnoun', 'la_pnoun', 'Cruz_pnoun', 'Z2']
# ['Carbajales_pnoun', 'de_pnoun', 'Alba_pnoun', 'Z2']
# ['Carbajosa_pnoun', 'de_pnoun', 'la_pnoun', 'Sagrada_pnoun', 'Z2']
# ['Carballeda_pnoun', 'de_pnoun', 'Avia_pnoun', 'Z2']
# ['Carballeda_pnoun', 'de_pnoun', 'Valdeorras_pnoun', 'Z2']
# ['Carboneras_pnoun', 'de_pnoun', 'Guadaza\xc3\xb3n_pnoun', 'Z2']
# ['Carbonero_pnoun', 'el_pnoun', 'Mayor_pnoun', 'Z2']
# ['Carcedo_pnoun', 'de_pnoun', 'Bureba_pnoun', 'Z2']
# ['Carcedo_pnoun', 'de_pnoun', 'Burgos_pnoun', 'Z2']
# ['Carde\xc3\xb1osa_pnoun', 'de_pnoun', 'Volpejera_pnoun', 'Z2']
# ['Carde\xc3\xb1uela_pnoun', 'Riopico_pnoun', 'Z2']
# ['Cardiel_pnoun', 'de_pnoun', 'los_pnoun', 'Montes_pnoun', 'Z2']
# ['cargar_verb', 'con_prep', 'el_art', 'mochuelo_noun', 'E2-', 'S1.1.2', 'A1.1.2']
# ['Carla_pnoun', 'Su\xc3\xa1rez_pnoun', 'Z2']
# ['Carla_pnoun', 'Su\xc3\xa1rez_pnoun', 'Navarro_pnoun', 'Z2']
# ['Carles_pnoun', 'Castillejo_pnoun', 'Z2']
# ['Carles_pnoun', 'Castillejo_pnoun', 'Salvador_pnoun', 'Z2']
# ['Carles_pnoun', 'Joanmart\xc3\xad_pnoun', 'Z2']
# ['Carlos_pnoun', 'Casta\xc3\xb1o_pnoun', 'Z2']
# ['Carlos_pnoun', 'Coloma_pnoun', 'Z2']
# ['Carlos_pnoun', 'Coloma_pnoun', 'Nicol\xc3\xa1s_pnoun', 'Z2']
# ['Carlos_pnoun', 'Garc\xc3\xada_pnoun', 'Z2']
# ['Carlos_pnoun', 'Jim\xc3\xa9nez_pnoun', 'Z2']
# ['Carlos_pnoun', 'Jim\xc3\xa9nez_pnoun', 'S\xc3\xa1nchez_pnoun', 'Z2']
# ['Carlos_pnoun', 'Loriente_pnoun', 'Z2']
# ['Carlos_pnoun', 'Machado_pnoun', 'Z2']
# ['Carlos_pnoun', 'Machado_pnoun', 'Sobrados_pnoun', 'Z2']
# ['Carlos_pnoun', 'Moy\xc3\xa1_pnoun', 'Z2']
# ['Carlos_pnoun', 'P\xc3\xa9rez_pnoun', 'Z2']
# ['Carlos_pnoun', 'P\xc3\xa9rez_pnoun', 'Rial_pnoun', 'Z2']
# ['Carlos_pnoun', 'Prieto_pnoun', 'Z2']
# ['Carlos_pnoun', 'Prieto_pnoun', 'Martos_pnoun', 'Z2']
# ['Carlos_pnoun', 'Sastre_pnoun', 'Z2']
# ['Carlos_pnoun', 'Sastre_pnoun', 'Candil_pnoun', 'Z2']
# ['Carlos_pnoun', 'Torrent_pnoun', 'Z2']
# ['Carlota_pnoun', 'Castrejana_pnoun', 'Fern\xc3\xa1ndez_pnoun', 'Z2']
# ['carne_noun', 'de_prep', 'ca\xc3\xb1\xc3\xb3n_noun', 'A2', 'A5']
# ['Carolina_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Z2']
# ['Carpio_pnoun', 'de_pnoun', 'Azaba_pnoun', 'Z2']
# ['Carrascal_pnoun', 'de_pnoun', 'Barregas_pnoun', 'Z2']
# ['Carrascal_pnoun', 'del_pnoun', 'Obispo_pnoun', 'Z2']
# ['Carrascal_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Carrascosa_pnoun', 'de_pnoun', 'Abajo_pnoun', 'Z2']
# ['Carrascosa_pnoun', 'de_pnoun', 'Haro_pnoun', 'Z2']
# ['Carrascosa_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Carri\xc3\xb3n_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Carri\xc3\xb3n_pnoun', 'de_pnoun', 'los_pnoun', 'C\xc3\xa9spedes_pnoun', 'Z2']
# ['Carri\xc3\xb3n_pnoun', 'de_pnoun', 'los_pnoun', 'Condes_pnoun', 'Z2']
# ['Casa_pnoun', 'de_pnoun', 'Uceda_pnoun', 'Z2']
# ['Casar_pnoun', 'de_pnoun', 'C\xc3\xa1ceres_pnoun', 'Z2']
# ['Casar_pnoun', 'de_pnoun', 'Palomero_pnoun', 'Z2']
# ['Casares_pnoun', 'de_pnoun', 'las_pnoun', 'Hurdes_pnoun', 'Z2']
# ['Casarrubios_pnoun', 'del_pnoun', 'Monte_pnoun', 'Z2']
# ['Casas_pnoun', 'Altas_pnoun', 'Z2']
# ['Casas_pnoun', 'Bajas_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Ben\xc3\xadtez_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Don_pnoun', 'Antonio_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Don_pnoun', 'G\xc3\xb3mez_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Don_pnoun', 'Pedro_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Fernando_pnoun', 'Alonso_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Garcimolina_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Guijarro_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Haro_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Juan_pnoun', 'N\xc3\xba\xc3\xb1ez_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'L\xc3\xa1zaro_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'los_pnoun', 'Pinos_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Mill\xc3\xa1n_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Miravete_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Reina_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'San_pnoun', 'Galindo_pnoun', 'Z2']
# ['Casas_pnoun', 'de_pnoun', 'Ves_pnoun', 'Z2']
# ['Casas_pnoun', 'del_pnoun', 'Casta\xc3\xb1ar_pnoun', 'Z2']
# ['Casas_pnoun', 'del_pnoun', 'Monte_pnoun', 'Z2']
# ['Casas_pnoun', 'del_pnoun', 'Puerto_pnoun', 'Z2']
# ['Casaseca_pnoun', 'de_pnoun', 'Campe\xc3\xa1n_pnoun', 'Z2']
# ['Casaseca_pnoun', 'de_pnoun', 'las_pnoun', 'Chanas_pnoun', 'Z2']
# ['Casasola_pnoun', 'de_pnoun', 'Ari\xc3\xb3n_pnoun', 'Z2']
# ['Casbas_pnoun', 'de_pnoun', 'Huesca_pnoun', 'Z2']
# ['Cascajares_pnoun', 'de_pnoun', 'Bureba_pnoun', 'Z2']
# ['Cascajares_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Cascante_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Casillas_pnoun', 'de_pnoun', 'Coria_pnoun', 'Z2']
# ['Casillas_pnoun', 'de_pnoun', 'Flores_pnoun', 'Z2']
# ['Cass\xc3\xa0_pnoun', 'de_pnoun', 'la_pnoun', 'Selva_pnoun', 'Z2']
# ['Casta\xc3\xb1ar_pnoun', 'de_pnoun', 'Ibor_pnoun', 'Z2']
# ['Casta\xc3\xb1ares_pnoun', 'de_pnoun', 'Rioja_pnoun', 'Z2']
# ['Casta\xc3\xb1o_pnoun', 'del_pnoun', 'Robledo_pnoun', 'Z2']
# ['Castej\xc3\xb3n_pnoun', 'de_pnoun', 'Alarba_pnoun', 'Z2']
# ['Castej\xc3\xb3n_pnoun', 'de_pnoun', 'Henares_pnoun', 'Z2']
# ['Castej\xc3\xb3n_pnoun', 'de_pnoun', 'las_pnoun', 'Armas_pnoun', 'Z2']
# ['Castej\xc3\xb3n_pnoun', 'de_pnoun', 'Monegros_pnoun', 'Z2']
# ['Castej\xc3\xb3n_pnoun', 'de_pnoun', 'Sos_pnoun', 'Z2']
# ['Castej\xc3\xb3n_pnoun', 'de_pnoun', 'Tornos_pnoun', 'Z2']
# ['Castej\xc3\xb3n_pnoun', 'de_pnoun', 'Valdejasa_pnoun', 'Z2']
# ['Castej\xc3\xb3n_pnoun', 'del_pnoun', 'Puente_pnoun', 'Z2']
# ['Castel_pnoun', 'de_pnoun', 'Cabra_pnoun', 'Z2']
# ['Castell_pnoun', 'de_pnoun', 'Cabres_pnoun', 'Z2']
# ['Castell_pnoun', 'de_pnoun', 'Castells_pnoun', 'Z2']
# ['Castell_pnoun', 'de_pnoun', "L'areny_pnoun", 'Z2']
# ['Castell_pnoun', 'de_pnoun', 'Mur_pnoun', 'Z2']
# ['Castell-Platja_pnoun', "D'aro_pnoun", 'Z2']
# ['Castellanos_pnoun', 'de_pnoun', 'Castro_pnoun', 'Z2']
# ['Castellanos_pnoun', 'de_pnoun', 'Moriscos_pnoun', 'Z2']
# ['Castellanos_pnoun', 'de_pnoun', 'Villiquera_pnoun', 'Z2']
# ['Castellanos_pnoun', 'de_pnoun', 'Zapardiel_pnoun', 'Z2']
# ['Castellar_pnoun', 'de_pnoun', 'la_pnoun', 'Frontera_pnoun', 'Z2']
# ['Castellar_pnoun', 'de_pnoun', 'la_pnoun', 'Muela_pnoun', 'Z2']
# ['Castellar_pnoun', 'de_pnoun', 'la_pnoun', 'Ribera_pnoun', 'Z2']
# ['Castellar_pnoun', 'de_pnoun', "N'hug_pnoun", 'Z2']
# ['Castellar_pnoun', 'de_pnoun', 'Santiago_pnoun', 'Z2']
# ['Castellar_pnoun', 'del_pnoun', 'Riu_pnoun', 'Z2']
# ['Castellar_pnoun', 'del_pnoun', 'Vall\xc3\xa8s_pnoun', 'Z2']
# ['Castellbell_pnoun', 'I_pnoun', 'el_pnoun', 'Vilar_pnoun', 'Z2']
# ['Castellet_pnoun', 'I_pnoun', 'la_pnoun', 'Gornal_pnoun', 'Z2']
# ['Castellfollit_pnoun', 'de_pnoun', 'la_pnoun', 'Roca_pnoun', 'Z2']
# ['Castellfollit_pnoun', 'de_pnoun', 'Riubreg\xc3\xb3s_pnoun', 'Z2']
# ['Castellfollit_pnoun', 'del_pnoun', 'Boix_pnoun', 'Z2']
# ['Castellnou_pnoun', 'de_pnoun', 'Bages_pnoun', 'Z2']
# ['Castellnou_pnoun', 'de_pnoun', 'Seana_pnoun', 'Z2']
# ['Castell\xc3\xb3_pnoun', "D'emp\xc3\xbaries_pnoun", 'Z2']
# ['Castell\xc3\xb3_pnoun', 'de_pnoun', 'Farfanya_pnoun', 'Z2']
# ['Castell\xc3\xb3_pnoun', 'de_pnoun', 'la_pnoun', 'Plana_pnoun', 'Z2']
# ['Castell\xc3\xb3_pnoun', 'de_pnoun', 'Rugat_pnoun', 'Z2']
# ['Castell\xc3\xb3n_pnoun', 'de_pnoun', 'la_pnoun', 'Plana_pnoun', 'Z2']
# ['Castellonet_pnoun', 'de_pnoun', 'la_pnoun', 'Conquesta_pnoun', 'Z2']
# ['Castellvell_pnoun', 'del_pnoun', 'Camp_pnoun', 'Z2']
# ['Castellv\xc3\xad_pnoun', 'de_pnoun', 'la_pnoun', 'Marca_pnoun', 'Z2']
# ['Castellv\xc3\xad_pnoun', 'de_pnoun', 'Rosanes_pnoun', 'Z2']
# ['Castiello_pnoun', 'de_pnoun', 'Jaca_pnoun', 'Z2']
# ['Castil_pnoun', 'de_pnoun', 'Peones_pnoun', 'Z2']
# ['Castil_pnoun', 'de_pnoun', 'Vela_pnoun', 'Z2']
# ['Castilblanco_pnoun', 'de_pnoun', 'los_pnoun', 'Arroyos_pnoun', 'Z2']
# ['Castilfr\xc3\xado_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Castilleja_pnoun', 'de_pnoun', 'Guzm\xc3\xa1n_pnoun', 'Z2']
# ['Castilleja_pnoun', 'de_pnoun', 'la_pnoun', 'Cuesta_pnoun', 'Z2']
# ['Castilleja_pnoun', 'del_pnoun', 'Campo_pnoun', 'Z2']
# ['Castillejo_pnoun', 'de_pnoun', 'Iniesta_pnoun', 'Z2']
# ['Castillejo_pnoun', 'de_pnoun', 'Mart\xc3\xadn_pnoun', 'Viejo_pnoun', 'Z2']
# ['Castillejo_pnoun', 'de_pnoun', 'Mesle\xc3\xb3n_pnoun', 'Z2']
# ['Castillejo_pnoun', 'de_pnoun', 'Robledo_pnoun', 'Z2']
# ['Castillo_pnoun', 'de_pnoun', 'Bayuela_pnoun', 'Z2']
# ['Castillo_pnoun', 'de_pnoun', 'Garcimu\xc3\xb1oz_pnoun', 'Z2']
# ['Castillo_pnoun', 'de_pnoun', 'Locub\xc3\xadn_pnoun', 'Z2']
# ['Castillo_pnoun', 'de_pnoun', 'Villamalefa_pnoun', 'Z2']
# ['Castrej\xc3\xb3n_pnoun', 'de_pnoun', 'la_pnoun', 'Pe\xc3\xb1a_pnoun', 'Z2']
# ['Castrej\xc3\xb3n_pnoun', 'de_pnoun', 'Trabancos_pnoun', 'Z2']
# ['Castrelo_pnoun', 'de_pnoun', 'Mi\xc3\xb1o_pnoun', 'Z2']
# ['Castrelo_pnoun', 'Do_pnoun', 'Val_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'Cabrera_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'Don_pnoun', 'Juan_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'Duero_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'la_pnoun', 'Guare\xc3\xb1a_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'la_pnoun', 'Reina_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'la_pnoun', 'Valduerna_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'la_pnoun', 'Vega_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'Onielo_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'Riopisuerga_pnoun', 'Z2']
# ['Castrillo_pnoun', 'de_pnoun', 'Villavega_pnoun', 'Z2']
# ['Castrillo_pnoun', 'del_pnoun', 'Val_pnoun', 'Z2']
# ['Castrillo_pnoun', 'Mota_pnoun', 'de_pnoun', 'Jud\xc3\xados_pnoun', 'Z2']
# ['Castro_pnoun', 'Caldelas_pnoun', 'Z2']
# ['Castro_pnoun', 'de_pnoun', 'Filabres_pnoun', 'Z2']
# ['Castro_pnoun', 'de_pnoun', 'Fuentidue\xc3\xb1a_pnoun', 'Z2']
# ['Castro_pnoun', 'de_pnoun', 'Rei_pnoun', 'Z2']
# ['Castro_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Castronuevo_pnoun', 'de_pnoun', 'Esgueva_pnoun', 'Z2']
# ['Castroserna_pnoun', 'de_pnoun', 'Abajo_pnoun', 'Z2']
# ['Castrotierra_pnoun', 'de_pnoun', 'Valmadrigal_pnoun', 'Z2']
# ['Castroverde_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Castroverde_pnoun', 'de_pnoun', 'Cerrato_pnoun', 'Z2']
# ['Caudete_pnoun', 'de_pnoun', 'las_pnoun', 'Fuentes_pnoun', 'Z2']
# ['Cazalla_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Cebrones_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ...
# ['Villalba_pnoun', 'de_pnoun', 'Guardo_pnoun', 'Z2']
# ['Villalba_pnoun', 'de_pnoun', 'la_pnoun', 'Lampreana_pnoun', 'Z2']
# ['Villalba_pnoun', 'de_pnoun', 'la_pnoun', 'Loma_pnoun', 'Z2']
# ['Villalba_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Villalba_pnoun', 'de_pnoun', 'los_pnoun', 'Alcores_pnoun', 'Z2']
# ['Villalba_pnoun', 'de_pnoun', 'los_pnoun', 'Barros_pnoun', 'Z2']
# ['Villalba_pnoun', 'de_pnoun', 'los_pnoun', 'Llanos_pnoun', 'Z2']
# ['Villalba_pnoun', 'de_pnoun', 'Perejil_pnoun', 'Z2']
# ['Villalba_pnoun', 'de_pnoun', 'Rioja_pnoun', 'Z2']
# ['Villalba_pnoun', 'del_pnoun', 'Alcor_pnoun', 'Z2']
# ['Villalba_pnoun', 'del_pnoun', 'Rey_pnoun', 'Z2']
# ['Villalbilla_pnoun', 'de_pnoun', 'Burgos_pnoun', 'Z2']
# ['Villalbilla_pnoun', 'de_pnoun', 'Gumiel_pnoun', 'Z2']
# ['Villalc\xc3\xa1zar_pnoun', 'de_pnoun', 'Sirga_pnoun', 'Z2']
# ['Villalgordo_pnoun', 'del_pnoun', 'J\xc3\xbacar_pnoun', 'Z2']
# ['Villalgordo_pnoun', 'del_pnoun', 'Marquesado_pnoun', 'Z2']
# ['Villalobar_pnoun', 'de_pnoun', 'Rioja_pnoun', 'Z2']
# ['Villal\xc3\xb3n_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Villaluenga_pnoun', 'de_pnoun', 'la_pnoun', 'Sagra_pnoun', 'Z2']
# ['Villaluenga_pnoun', 'de_pnoun', 'la_pnoun', 'Vega_pnoun', 'Z2']
# ['Villaluenga_pnoun', 'del_pnoun', 'Rosario_pnoun', 'Z2']
# ['Villamanrique_pnoun', 'de_pnoun', 'la_pnoun', 'Condesa_pnoun', 'Z2']
# ['Villamanrique_pnoun', 'de_pnoun', 'Tajo_pnoun', 'Z2']
# ['Villamart\xc3\xadn_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Villamart\xc3\xadn_pnoun', 'de_pnoun', 'Don_pnoun', 'Sancho_pnoun', 'Z2']
# ['Villamayor_pnoun', 'de_pnoun', 'Calatrava_pnoun', 'Z2']
# ['Villamayor_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Villamayor_pnoun', 'de_pnoun', 'G\xc3\xa1llego_pnoun', 'Z2']
# ['Villamayor_pnoun', 'de_pnoun', 'los_pnoun', 'Montes_pnoun', 'Z2']
# ['Villamayor_pnoun', 'de_pnoun', 'Monjard\xc3\xadn_pnoun', 'Z2']
# ['Villamayor_pnoun', 'de_pnoun', 'Santiago_pnoun', 'Z2']
# ['Villamayor_pnoun', 'de_pnoun', 'Trevi\xc3\xb1o_pnoun', 'Z2']
# ['Villamediana_pnoun', 'de_pnoun', 'Iregua_pnoun', 'Z2']
# ['Villamiel_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Villamiel_pnoun', 'de_pnoun', 'Toledo_pnoun', 'Z2']
# ['Villamont\xc3\xa1n_pnoun', 'de_pnoun', 'la_pnoun', 'Valduerna_pnoun', 'Z2']
# ['Villamor_pnoun', 'de_pnoun', 'los_pnoun', 'Escuderos_pnoun', 'Z2']
# ['Villamoratiel_pnoun', 'de_pnoun', 'las_pnoun', 'Matas_pnoun', 'Z2']
# ['Villamuera_pnoun', 'de_pnoun', 'la_pnoun', 'Cueza_pnoun', 'Z2']
# ['Villamuriel_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Villamuriel_pnoun', 'de_pnoun', 'Cerrato_pnoun', 'Z2']
# ['Vill\xc3\xa1n_pnoun', 'de_pnoun', 'Tordesillas_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Aezkoa_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Alcardete_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Alcor\xc3\xb3n_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Algaidas_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Arga\xc3\xb1o_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Argecilla_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', '\xc3\x81vila_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Azoague_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Bogas_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Cameros_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Campe\xc3\xa1n_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Carazo_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Castell\xc3\xb3n_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'C\xc3\xb3rdoba_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Duero_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'G\xc3\xa1llego_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'G\xc3\xb3mez_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Gormaz_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Guadamejud_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Gumiel_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Huerva_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Jiloca_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Ca\xc3\xb1ada_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Concepci\xc3\xb3n_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Condesa_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Fuente_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Jara_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Reina_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Serena_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Torre_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'la_pnoun', 'Vera_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'las_pnoun', 'Cruces_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'las_pnoun', 'Manzanas_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'las_pnoun', 'Peras_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'las_pnoun', 'Torres_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'los_pnoun', 'Caballeros_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'los_pnoun', 'Castillejos_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'los_pnoun', 'Infantes_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Oscos_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Perales_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'San_pnoun', 'Carlos_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'San_pnoun', 'Juan_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'San_pnoun', 'Mancio_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Sigena_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Tapia_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Teba_pnoun', 'Z2']
# ['Villanueva_pnoun', 'de_pnoun', 'Viver_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Aceral_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Ariscal_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Arzobispo_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Campillo_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Campo_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Conde_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Duque_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Fresno_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Pardillo_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Rebollar_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Rebollar_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Rey_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Segura_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'y_pnoun', 'Minas_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Rosario_pnoun', 'Z2']
# ['Villanueva_pnoun', 'del_pnoun', 'Trabuco_pnoun', 'Z2']
# ['Villanueva_pnoun', 'Mes\xc3\xada_pnoun', 'Z2']
# ['Villanu\xc3\xb1o_pnoun', 'de_pnoun', 'Valdavia_pnoun', 'Z2']
# ['Villaobispo_pnoun', 'de_pnoun', 'Otero_pnoun', 'Z2']
# ['Villaornate_pnoun', 'y_pnoun', 'Castro_pnoun', 'Z2']
# ['Villaquir\xc3\xa1n_pnoun', 'de_pnoun', 'la_pnoun', 'Puebla_pnoun', 'Z2']
# ['Villaquir\xc3\xa1n_pnoun', 'de_pnoun', 'los_pnoun', 'Infantes_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Arga\xc3\xb1\xc3\xa1n_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Ca\xc3\xb1as_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Ciervo_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Corneja_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Domingo_pnoun', 'Garc\xc3\xada_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Fallaves_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Gallimazo_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'la_pnoun', 'Encina_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'la_pnoun', 'Yegua_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'los_pnoun', 'Navarros_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Olalla_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Peralonso_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Plasencia_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Rena_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Samaniego_pnoun', 'Z2']
# ['Villar_pnoun', 'de_pnoun', 'Torre_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Ala_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Arzobispo_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Buey_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Campo_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Cobo_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Humo_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Infantado_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Olmo_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Pedroso_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Pozo_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Rey_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Villar_pnoun', 'del_pnoun', 'Salz_pnoun', 'Z2']
# ['Villar_pnoun', 'y_pnoun', 'Velasco_pnoun', 'Z2']
# ['Villarcayo_pnoun', 'de_pnoun', 'Merindad_pnoun', 'de_pnoun', 'Castilla_pnoun', 'la_pnoun', 'Vieja_pnoun', 'Z2']
# ['Villardiegua_pnoun', 'de_pnoun', 'la_pnoun', 'Ribera_pnoun', 'Z2']
# ['Villarejo_pnoun', 'de_pnoun', 'Fuentes_pnoun', 'Z2']
# ['Villarejo_pnoun', 'de_pnoun', 'la_pnoun', 'Pe\xc3\xb1uela_pnoun', 'Z2']
# ['Villarejo_pnoun', 'de_pnoun', 'Montalb\xc3\xa1n_pnoun', 'Z2']
# ['Villarejo_pnoun', 'de_pnoun', '\xc3\x93rbigo_pnoun', 'Z2']
# ['Villarejo_pnoun', 'de_pnoun', 'Salvan\xc3\xa9s_pnoun', 'Z2']
# ['Villarejo_pnoun', 'del_pnoun', 'Valle_pnoun', 'Z2']
# ['Villares_pnoun', 'de_pnoun', 'Jadraque_pnoun', 'Z2']
# ['Villares_pnoun', 'de_pnoun', 'la_pnoun', 'Reina_pnoun', 'Z2']
# ['Villares_pnoun', 'de_pnoun', '\xc3\x93rbigo_pnoun', 'Z2']
# ['Villares_pnoun', 'de_pnoun', 'Yeltes_pnoun', 'Z2']
# ['Villares_pnoun', 'del_pnoun', 'Saz_pnoun', 'Z2']
# ['Villargordo_pnoun', 'del_pnoun', 'Cabriel_pnoun', 'Z2']
# ['Villarino_pnoun', 'de_pnoun', 'los_pnoun', 'Aires_pnoun', 'Z2']
# ['Villarmentero_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Villarmentero_pnoun', 'de_pnoun', 'Esgueva_pnoun', 'Z2']
# ['Villarreal_pnoun', 'de_pnoun', 'Huerva_pnoun', 'Z2']
# ['Villarr\xc3\xadn_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Villarroya_pnoun', 'de_pnoun', 'la_pnoun', 'Sierra_pnoun', 'Z2']
# ['Villarroya_pnoun', 'de_pnoun', 'los_pnoun', 'Pinares_pnoun', 'Z2']
# ['Villarroya_pnoun', 'del_pnoun', 'Campo_pnoun', 'Z2']
# ['Villarrubia_pnoun', 'de_pnoun', 'los_pnoun', 'Ojos_pnoun', 'Z2']
# ['Villarrubia_pnoun', 'de_pnoun', 'Santiago_pnoun', 'Z2']
# ['Villarta_pnoun', 'de_pnoun', 'los_pnoun', 'Montes_pnoun', 'Z2']
# ['Villarta_pnoun', 'de_pnoun', 'San_pnoun', 'Juan_pnoun', 'Z2']
# ['Villas_pnoun', 'de_pnoun', 'la_pnoun', 'Ventosa_pnoun', 'Z2']
# ['Villasbuenas_pnoun', 'de_pnoun', 'Gata_pnoun', 'Z2']
# ['Villaseca_pnoun', 'de_pnoun', 'Arciel_pnoun', 'Z2']
# ['Villaseca_pnoun', 'de_pnoun', 'Henares_pnoun', 'Z2']
# ['Villaseca_pnoun', 'de_pnoun', 'la_pnoun', 'Sagra_pnoun', 'Z2']
# ['Villaseca_pnoun', 'de_pnoun', 'Uceda_pnoun', 'Z2']
# ['Villaseco_pnoun', 'de_pnoun', 'los_pnoun', 'Gamitos_pnoun', 'Z2']
# ['Villaseco_pnoun', 'de_pnoun', 'los_pnoun', 'Reyes_pnoun', 'Z2']
# ['Villaseco_pnoun', 'del_pnoun', 'Pan_pnoun', 'Z2']
# ['Villasila_pnoun', 'de_pnoun', 'Valdavia_pnoun', 'Z2']
# ['Villasur_pnoun', 'de_pnoun', 'Herreros_pnoun', 'Z2']
# ['Villaverde_pnoun', 'de_pnoun', 'Guadalimar_pnoun', 'Z2']
# ['Villaverde_pnoun', 'de_pnoun', 'Guare\xc3\xb1a_pnoun', 'Z2']
# ['Villaverde_pnoun', 'de_pnoun', '\xc3\x8dscar_pnoun', 'Z2']
# ['Villaverde_pnoun', 'de_pnoun', 'Medina_pnoun', 'Z2']
# ['Villaverde_pnoun', 'de_pnoun', 'Montejo_pnoun', 'Z2']
# ['Villaverde_pnoun', 'de_pnoun', 'Rioja_pnoun', 'Z2']
# ['Villaverde_pnoun', 'del_pnoun', 'Monte_pnoun', 'Z2']
# ['Villaverde_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Z2']
# ['Villaverde_pnoun', 'y_pnoun', 'Pasaconsol_pnoun', 'Z2']
# ['Villaveza_pnoun', 'de_pnoun', 'Valverde_pnoun', 'Z2']
# ['Villaveza_pnoun', 'del_pnoun', 'Agua_pnoun', 'Z2']
# ['Villavicencio_pnoun', 'de_pnoun', 'los_pnoun', 'Caballeros_pnoun', 'Z2']
# ['Villaviciosa_pnoun', 'de_pnoun', 'C\xc3\xb3rdoba_pnoun', 'Z2']
# ['Villaviciosa_pnoun', 'de_pnoun', 'Od\xc3\xb3n_pnoun', 'Z2']
# ['Villavieja_pnoun', 'de_pnoun', 'Yeltes_pnoun', 'Z2']
# ['Villavieja_pnoun', 'del_pnoun', 'Lozoya_pnoun', 'Z2']
# ['Villayerno_pnoun', 'Morquillas_pnoun', 'Z2']
# ['Villazanzo_pnoun', 'de_pnoun', 'Valderaduey_pnoun', 'Z2']
# ['Villel_pnoun', 'de_pnoun', 'Mesa_pnoun', 'Z2']
# ['Viller\xc3\xadas_pnoun', 'de_pnoun', 'Campos_pnoun', 'Z2']
# ['Villoslada_pnoun', 'de_pnoun', 'Cameros_pnoun', 'Z2']
# ['Villota_pnoun', 'del_pnoun', 'P\xc3\xa1ramo_pnoun', 'Z2']
# ['Vilob\xc3\xad_pnoun', "D'onyar_pnoun", 'Z2']
# ['Vilob\xc3\xad_pnoun', 'del_pnoun', 'Pened\xc3\xa8s_pnoun', 'Z2']
# ['Viloria_pnoun', 'de_pnoun', 'Rioja_pnoun', 'Z2']
# ['Vilviestre_pnoun', 'del_pnoun', 'Pinar_pnoun', 'Z2']
# ['Vimbod\xc3\xad_pnoun', 'I_pnoun', 'Poblet_pnoun', 'Z2']
# ['Vi\xc3\xb1egra_pnoun', 'de_pnoun', 'Mora\xc3\xb1a_pnoun', 'Z2']
# ['Viniegra_pnoun', 'de_pnoun', 'Abajo_pnoun', 'Z2']
# ['Viniegra_pnoun', 'de_pnoun', 'Arriba_pnoun', 'Z2']
# ['Vinyols_pnoun', 'I_pnoun', 'Els_pnoun', 'Arcs_pnoun', 'Z2']
# ['Viran_pnoun', 'Morros_pnoun', 'Z2']
# ['Virginia_pnoun', 'Beach_pnoun', 'Z2']
# ['Virginia_pnoun', 'Ruano_pnoun', 'Z2']
# ['Virginia_pnoun', 'Ruano_pnoun', 'Pascual_pnoun', 'Z2']
# ['Viso_pnoun', 'del_pnoun', 'Marqu\xc3\xa9s_pnoun', 'Z2']
# ['Vistabella_pnoun', 'del_pnoun', 'Maestrat_pnoun', 'Z2']
# ['Vivel_pnoun', 'del_pnoun', 'R\xc3\xado_pnoun', 'Mart\xc3\xadn_pnoun', 'Z2']
# ['Viver_pnoun', 'I_pnoun', 'Serrateix_pnoun', 'Z2']
# ['Vivi_pnoun', 'Ruano_pnoun', 'Z2']
# ['Washington_pnoun', 'D.C._pnoun', 'Z2']
# ['Xabier_pnoun', 'Fern\xc3\xa1ndez_pnoun', 'Z2']
# ['Xabier_pnoun', 'Fern\xc3\xa1ndez_pnoun', 'Gazta\xc3\xb1aga_pnoun', 'Z2']
# ['Xavier_pnoun', 'Lleonart_pnoun', 'Z2']
# ['Xavier_pnoun', 'Lleonart_pnoun', 'Blanco_pnoun', 'Z2']
# ['Xavier_pnoun', 'Llobet_pnoun', 'Z2']
# ['Xavier_pnoun', "O'Callaghan_pnoun", 'Z2']
# ['Xavier_pnoun', 'Ribas_pnoun', 'Z2']
# ['Xavier_pnoun', 'Ribas_pnoun', 'Centelles_pnoun', 'Z2']
# ['Xavier_pnoun', 'Vall\xc3\xa8s_pnoun', 'Z2']
# ['Xavier_pnoun', 'Vall\xc3\xa8s_pnoun', 'Trias_pnoun', 'Z2']
# ['Xinzo_pnoun', 'de_pnoun', 'Limia_pnoun', 'Z2']
# ['Xunqueira_pnoun', 'de_pnoun', 'Amb\xc3\xada_pnoun', 'Z2']
# ['Xunqueira_pnoun', 'de_pnoun', 'Espadanedo_pnoun', 'Z2']
# ['Yago_pnoun', 'Lamela_pnoun', 'Z2']
# ['Yanfei_pnoun', 'Shen_pnoun', 'Z2']
# ['Yanfei_pnoun', 'Shen_pnoun', 'Zhang_pnoun', 'Z2']
# ['Yanguas_pnoun', 'de_pnoun', 'Eresma_pnoun', 'Z2']
# ['Yebra_pnoun', 'de_pnoun', 'Basa_pnoun', 'Z2']
# ['Yecla_pnoun', 'de_pnoun', 'Yeltes_pnoun', 'Z2']
# ['Y\xc3\xa9lamos_pnoun', 'de_pnoun', 'Abajo_pnoun', 'Z2']
# ['Y\xc3\xa9lamos_pnoun', 'de_pnoun', 'Arriba_pnoun', 'Z2']
# ['Yernes_pnoun', 'y_pnoun', 'Tameza_pnoun', 'Z2']
# ['Yesenia_pnoun', 'Centeno_pnoun', 'Z2']
# ['Yesenia_pnoun', 'Centeno_pnoun', 'Sousa_pnoun', 'Z2']
# ['Yoana_pnoun', 'Mart\xc3\xadnez_pnoun', 'Z2']
# ['Yoana_pnoun', 'Mart\xc3\xadnez_pnoun', 'Barbero_pnoun', 'Z2']
# ['Yunquera_pnoun', 'de_pnoun', 'Henares_pnoun', 'Z2']
# ['Yurema_pnoun', 'Requena_pnoun', 'Z2']
# ['Zafra_pnoun', 'de_pnoun', 'Z\xc3\xa1ncara_pnoun', 'Z2']
# ['Zalamea_pnoun', 'de_pnoun', 'la_pnoun', 'Serena_pnoun', 'Z2']
# ['Zalamea_pnoun', 'la_pnoun', 'Real_pnoun', 'Z2']
# ['Zapardiel_pnoun', 'de_pnoun', 'la_pnoun', 'Ca\xc3\xb1ada_pnoun', 'Z2']
# ['Zapardiel_pnoun', 'de_pnoun', 'la_pnoun', 'Ribera_pnoun', 'Z2']
# ['Zarza_pnoun', 'de_pnoun', 'Granadilla_pnoun', 'Z2']
# ['Zarza_pnoun', 'de_pnoun', 'Mont\xc3\xa1nchez_pnoun', 'Z2']
# ['Zarza_pnoun', 'de_pnoun', 'Tajo_pnoun', 'Z2']
# ['Zarza_pnoun', 'la_pnoun', 'Mayor_pnoun', 'Z2']
# ['Zarzosa_pnoun', 'de_pnoun', 'R\xc3\xado_pnoun', 'Pisuerga_pnoun', 'Z2']
# ['Zarzuela_pnoun', 'de_pnoun', 'Jadraque_pnoun', 'Z2']
# ['Zarzuela_pnoun', 'del_pnoun', 'Monte_pnoun', 'Z2']
# ['Zarzuela_pnoun', 'del_pnoun', 'Pinar_pnoun', 'Z2']
# ['Zhiwen_pnoun', 'He_pnoun', 'Z2']
# ['Zhiwen_pnoun', 'He_pnoun', 'Cheng_pnoun', 'Z2']
# ['Zizur_pnoun', 'Mayor_pnoun', 'Z2']
# ['Zizur_pnoun', 'Nagusia_pnoun', 'Z2']
# ['Zorita_pnoun', 'de_pnoun', 'la_pnoun', 'Frontera_pnoun', 'Z2']
# ['Zorita_pnoun', 'de_pnoun', 'los_pnoun', 'Canes_pnoun', 'Z2']
# ['Zorita_pnoun', 'del_pnoun', 'Maestrazgo_pnoun', 'Z2']
# ['Zotes_pnoun', 'del_pnoun', 'P\xc3\xa1ramo_pnoun', 'Z2']
# ['Zulema_pnoun', 'Fuentes-Pila_pnoun', 'Z2']
# ['Zulema_pnoun', 'Fuentes-Pila_pnoun', 'Ortiz_pnoun', 'Z2']
# ['Zuri\xc3\xb1e_pnoun', 'Rodr\xc3\xadguez_pnoun', 'Z2']
# ['zurrar_verb', 'la_art', 'badana_noun', 'S1.2.5', 'G2']
# []
# Terminado...:
